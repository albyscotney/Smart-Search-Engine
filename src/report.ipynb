# %% [markdown]
# # Project
#
# ## Author: 16923

# %%
import nltk
import pandas as pd
import numpy as np
import random
import datetime
from user import User
import favouriteplaylist
# The ideal soloutions from PS 9 have been altered used for this problem set. 
from streaming_service import StreamingService
from show import Show
import playlist
from cleaner import clean_text
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore') # Warning messages have been checked and are not relevant. This does not stop errors being generated.

# %% [markdown]
# # Intro

# %% [markdown]
# ## What am I going to do this project?
# I will complete three tasks in python using clean and efficient coding. The tasks are:
# 1) Create a class User, who will belong to a streaming service. Create a class for a favourite playlist, with inherited properties from playlist.
# 2) Develop a more sophisticated searching method using an inverted index.
# 3) Perform an analysis of the language used in Netflix titles and descriptions.

# %% [markdown]
# # Task 1

# %% [markdown]
# All the required parts of the class User and Favourite have been made, I shall provide a demonstration of it below. It should be noted that neither of these special playlists have a capacity option, being special playlists, these features are unnecessary.

# %% [markdown]
# ## How does it work?

# %%
a = Show('b','sfdg','adsfg','c',1234,'d','e','1','f','qewr')
z = Show('z','234f','23df','h',1567,'p','t','234f','w','gasd')

# User takes the users birthday as arguments: dd, mm, yyyy
me = User(19,7,1999)
print("-------- Watch Later --------")
# Watch later playlist
me.watch_later(a) # Add a show with watch_later(show)
me.watch_later(z)
me.play_watch_later('b') # Play a show with play_watch_later(show_title), you may leave show title blank and it will play the next in line.
me.dont_watch_later('z') # Remove a show from watch later with dont_watch_later(show_title)
# Once a show is played it should leave the playlist
print(me.get_watch_later())
print("--------- Favourite ---------")
# Favourite Playlist
# These work in an identically to watch_later, except when a show is played it is not removed
me.favourite(a)
me.favourite(z)
me.play_favourite('b') # If no show is named, it will play a random show from the list.
me.unfavourite('z')
print(me.get_favourites())
 
print("--------- Playlist Interactions ---------")
# If a show is played from favourites that is also in watch later, it is removed from watch later.
me.watch_later(a)
me.play_favourite('b')
print('watch later:', me.get_watch_later())
print('favourite:', me.get_favourites())

print("--------- Other features ---------")
me.get_age() # Returns the users age. This uses the current date to make sure it's accurate
me.get_history() # Returns all the shows that have been played (ignoring duplicates)
me.clear_history() # Removes all items from the useres history. 
me.get_history()
# Out:
# -------- Watch Later --------
# Playing the show b (1)
# {}
# --------- Favourite ---------
# Playing the show b (1)
# {'b': b (1234)}
# --------- Playlist Interactions ---------
# Playing the show b (1)
# watch later: {}
# favourite: {'b': b (1234)}
# --------- Other features ---------
# Your history has been cleared
# {}

# %% [markdown]
# ## Test
#
# Using try and except statements I shall test my code. If this chunk runs to the end, it behaves as expected.

# %%
me = User(19,7,1999)

# Add a show to watch later
try:
    me.watch_later(a)
except:
    assert False, f"Attempted to add show to watch_later but an error occured."

# Play the show from watch later
played_show = str(me.play_watch_later())
assert played_show =="b (1234)", f"Expected the string Playing the show b (1234) but {played_show} is given"

# We should fail to play a show now as there's no show to play
try:
    me.play_watch_later() 
except IndexError:
    pass
except:
    assert False, f"Play a show from an empty playlist: expected to raise IndexError but another errortype is raised."
else:
    assert False, f"Play a show from an empty playlist: expected to raise IndexError but no error is raised."

# add a show to watch later
try:
    me.watch_later(a)
except:
    assert False, f"Attempted to add show to watch_later but an error occured."

# Remove the show from watch later
try:
    me.dont_watch_later('b')
except:
    assert False, 'An error has occured'

# A show shouldn't play now as no show is in watch later
try:
    played_show = me.play_watch_later()
except IndexError:
    pass
except:
    assert False, f"Play a show by name that is not available: expected to raise IndexError but another errortype is raised."
else:
    assert False, f"Play a show by name that is not available: expected to raise IndexError but no error is raised."

# Add a show to favourites
try:
    me.favourite(a)
except:
    assert False, f"Attempted to add show to favourite but an error occured."

# Add a second show to favourites
try:
    me.favourite(z)
except:
    assert False, f"Attempted to add show to favourite but an error occured."
    
# Remove a show from favouritese
try:
    me.unfavourite('b')
except:
    assert False, 'An error has occured'

# Add a show to watch later
try:
    me.watch_later(z)
except:
    assert False, f"Attempted to add show to watch_later but an error occured."

# Currently one show is in favourite and watch_later (the same show)
# Playing a show from favourite should remove it from watch later but no favourites
played_show = str(me.play_favourite()) # Only z is in favourite, it is also in watch_later, they should both be removed.
assert played_show =="z (1567)", f"Expected the string Playing the show b (1234) but {played_show} is given"

# Try and play a show from watch later, it shouldn't run
try:
    played_show = me.play_watch_later()
except IndexError:
    pass
except:
    assert False, f"Play a show by name that is not available: expected to raise IndexError but another errortype is raised."
else:
    assert False, f"Play a show by name that is not available: expected to raise IndexError but no error is raised."

# Play the same show again from favourites.
played_show = str(me.play_favourite())
assert played_show =="z (1567)", f"Expected the string Playing the show b (1234) but {played_show} is given"

# Get the age of the user
age = (me.get_age())
assert age == 21, f"Expected 21 but {age} is given"

# Now to test history
me = User(22,3,1962)

# We've just made it so history shouldn't be blank
hist = me.get_history()
assert hist == {}, f"Expected empty dictonary but {hist} given"

# Add a show to watch later
try:
    me.watch_later(a)
except:
    assert False, f"Attempted to add show to watch_later but an error occured."

# Play the show from watch later
played_show = str(me.play_watch_later())
assert played_show =="b (1234)", f"Expected the string Playing the show b (1234) but {played_show} is given"

# Check the show has been added the history
hist = (me.get_history())
assert list(hist.keys()) == ['b'], f"Expected dictionary with show b (1234) but {hist} given"

#Add show to favourite
try:
    me.favourite(z)
except:
    assert False, f"Attempted to add show to watch_later but an error occured."

# Play the show from favourites
played_show = str(me.play_favourite())
assert played_show =="z (1567)", f"Expected the string Playing the show b (1234) but {played_show} is given"

# Check it's been addeed to history
hist = (me.get_history())
assert list(hist.keys()) == ['b', 'z'], f"Expected dictionary with show 'b' and 'z' as keys) but {hist} given"

# Clear the history
try:
    me.clear_history()
except:
    assert "An unexpected error has arisen"

# Check the history is empty
hist = me.get_history()
assert hist == {}, f"Expected empty dictonary but {hist} given"
# Out:
# Playing the show b (1)
# Playing the show z (234f)
# Playing the show z (234f)
# Playing the show b (1)
# Playing the show z (234f)
# Your history has been cleared

# %% [markdown]
# As the code runs to the end without error, the test is successful.

# %% [markdown]
# # Task 2
#
# ## Program design
#
# My inverted index is built around a class. I chose to use a class rather than a function as it gives the ability to add to the index after it has been made, and to return the index without rebuilding it when it's needed. You would need to make numerous functions to do the same thing; this would be untidy and not very user friendly. A class also allows for other streaming services to be loaded in with ease.
#
# My inverted index makes use of a dictionary. This is because a dictionary is a sort of hash table with the words as the keys. This means it takes constant time, O(1) to access a word in the dictionary. This is preferred over other techniques such as a list of lists with [[word, [indexes], [word_2, indexes] ... ] as this would take O(n) to cycle through to check if a word is present.
#
# In the dictionary, the word corresponds to a list of values. Finding a value in these lists has maximum running time O(n), in the case every show has the same word. However, the average runtime will be much less as all the stop words have been removed, so no single word will appear in nearly all the shows.
#
# I cleaned my text with a function that I made. By using a function, it can be used as needed, and the code can be recycled for inputs of the search, question 3, and whenever else it’s needed.

# %% [markdown]
# ## Implementation

# %%
netflix_data_raw = pd.read_csv('../data/netflix_titles.csv')
netflix_data = netflix_data_raw[['title', 'director', 'cast', 'country', 'type', 'date_added', 'rating', 'duration', 'listed_in', 'description']]
netflix_data.head() # The data has loaded in correctly
# Out:
#    title           director  \
# 0     3%                NaN
# 1   7:19  Jorge Michel Grau
# 2  23:59       Gilbert Chan
# 3      9        Shane Acker
# 4     21     Robert Luketic
#
#                                                 cast        country     type  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil  TV Show
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico    Movie
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore    Movie
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States    Movie
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States    Movie
#
#           date_added rating   duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %%
netflix = StreamingService('Netflix', netflix_data)

# %%
netflix.search('chess')
# Out:
# [Searching for Bobby Fischer (Movie),
#  The Queen's Gambit (TV Show),
#  Magnus (Movie),
#  The Coldest Game (Movie),
#  Creating The Queen's Gambit (Movie)]

# %%
netflix.search('the - chESs %champion')
# Out:
# [Magnus (Movie)]

# %%
netflix.search('tim, %Timed!!! !travelling &movies')
# Out:
# [About Time (Movie)]

# %% [markdown]
# I have written an additional optional argument for the search function called 'unsure'. If unsure is set to true, it shall return all the shows that match any word in the given phrase (except stop words). The output is ordered by the number of matches made.

# %%
netflix.search('tim, %Timed!!! !travelling &movies dad', True)
# Out:
# [About Time (Movie),
#  Big Time Movie (Movie),
#  The Time Traveler's Wife (Movie),
#  Yo-Kai Watch: The Movie (Movie),
#  Anesthesia (Movie),
#  Enemy (Movie),
#  Garfield's Fun Fest (Movie),
#  Hans Zimmer: Live in Prague (Movie),
#  The Cakemaker (Movie),
#  Tim Allen: Men Are Pigs (Movie),
#  Tim Allen: ReWires America (Movie),
#  Tim Minchin And The Heritage Orchestra Live (Movie),
#  Tim Minchin: So F**king Rock (Movie),
#  Abby Sen (Movie),
#  Action Replayy (Movie),
#  AK vs AK (Movie),
#  Awe (Movie),
#  InuYasha the Movie: Affections Touching Across Time (Movie),
#  Long Time Running (Movie),
#  Monster High: Freaky Fusion (Movie),
#  Once Upon a Time in Mumbai Dobaara! (Movie),
#  Safety Not Guaranteed (Movie),
#  Scream 3 (Movie),
#  Spirit Riding Free: Spirit of Christmas (Movie),
#  The Time Machine (Movie),
#  يوم الدين (Movie),
#  Blinky Bill: The Movie (Movie),
#  Fishtronaut: The Movie (Movie),
#  My Travel Buddy (Movie),
#  Dad Wanted (Movie),
#  Scary Movie 5 (Movie),
#  The Larva Island Movie (Movie),
#  1 Mile to You (Movie),
#  3 Türken & ein Baby (Movie),
#  6 Balloons (Movie),
#  6 Days (Movie),
#  93 Days (Movie),
#  Automata (Movie),
#  Avicii: True Stories (Movie),
#  Bedtime Stories (Movie),
#  Big Miracle (Movie),
#  Brave Blue World: Racing to Solve Our Water Crisis (Movie),
#  Charlie and the Chocolate Factory (Movie),
#  Christmas with the Kranks (Movie),
#  Deidra & Laney Rob a Train (Movie),
#  Employee of the Month (Movie),
#  Fear and Loathing in Las Vegas (Movie),
#  First Love (Movie),
#  Four Christmases (Movie),
#  Freaks – You're One of Us (Movie),
#  Hardcore Henry (Movie),
#  Hop (Movie),
#  Hubie Halloween (Movie),
#  Kill Command (Movie),
#  Kung Fu Panda: Holiday (Movie),
#  Little Lunch: The Halloween Horror Story (Movie),
#  Lockout (Movie),
#  Love Wedding Repeat (Movie),
#  Mad Max (Movie),
#  MI-5 (Movie),
#  Michael Bolton's Big, Sexy Valentine's Day Special (Movie),
#  MR. RIGHT (Movie),
#  National Lampoon's Loaded Weapon 1 (Movie),
#  Norm of the North: Keys to the Kingdom (Movie),
#  Norm of the North: King Sized Adventure (Movie),
#  Operator (Movie),
#  Pahuyut Fighting Beat (Movie),
#  Pulp Fiction (Movie),
#  Red Trees (Movie),
#  Seven Pounds (Movie),
#  Star Wars: Episode VIII: The Last Jedi (Movie),
#  Sweeney Todd: The Demon Barber of Fleet Street (Movie),
#  The Confirmation (Movie),
#  The Little Vampire (Movie),
#  The Smurfs (Movie),
#  The Sunshine Makers (Movie),
#  The Wrong Missy (Movie),
#  Waarrior Savitri (Movie),
#  Walt Disney Animation Studios Short Films Collection (Movie),
#  Zoom (Movie),
#  Çok Filim Hareketler Bunlar (Movie),
#  A Secret Love (Movie),
#  A Wrinkle in Time (Movie),
#  American Masters: Ted Williams (Movie),
#  Angela's Christmas Wish (Movie),
#  ARQ (Movie),
#  Austin Powers: The Spy Who Shagged Me (Movie),
#  Bert Kreischer: Secret Time (Movie),
#  Bobby Robson: More Than a Manager (Movie),
#  Bon Cop Bad Cop 2 (Movie),
#  Brother's Shadow (Movie),
#  Captain Underpants Mega Blissmas (Movie),
#  Circus of Books (Movie),
#  Darna Mana Hai (Movie),
#  Door Ke Darshan (Movie),
#  Eggnoid: Love & Time Portal (Movie),
#  Every Time I Die (Movie),
#  Fate/Grand Order -First Order- (Movie),
#  Fatso (Movie),
#  Fireplace 4K: Crackling Birchwood from Fireplace for Your Home (Movie),
#  Fireworks (Movie),
#  Franca: Chaos and Creation (Movie),
#  Golden Time (Movie),
#  Good Luck Chuck (Movie),
#  Good Time (Movie),
#  Hairspray (Movie),
#  Happy Times (Movie),
#  Heritages (Movie),
#  Iceman (Movie),
#  Jack of all Trades (Movie),
#  Just Another Christmas (Movie),
#  Kalushi: The Story of Solomon Mahlangu (Movie),
#  Last Breath (Movie),
#  Little Singham: Kaal Ka Badla (Movie),
#  Little Singham: Mahabali (Movie),
#  Love Is Blind (Movie),
#  Lucky: No Time for Love (Movie),
#  Mantra (Movie),
#  Monster High: Ghouls Rule (Movie),
#  Mr. Peabody & Sherman (Movie),
#  Mumbai Delhi Mumbai (Movie),
#  My Perfect Romance (Movie),
#  Naked (Movie),
#  NOVA: Bird Brain (Movie),
#  Once Upon a Time in London (Movie),
#  Once Upon a Time in Mumbaai (Movie),
#  Once Upon a Time in the West (Movie),
#  Outside In (Movie),
#  Power Rangers Super Samurai: Stuck on Christmas (Movie),
#  Project Papa (Movie),
#  Punjab 1984 (Movie),
#  Rainbow Time (Movie),
#  Rising High (Movie),
#  Running Out Of Time (Movie),
#  Santa Claws (Movie),
#  Savage Dog (Movie),
#  Schubert In Love (Movie),
#  See You Yesterday (Movie),
#  Shimmer Lake (Movie),
#  Spy Kids: All the Time in the World (Movie),
#  Spy Time (Movie),
#  Super Dark Times (Movie),
#  Super Monsters: Santa’s Super Monster Helpers (Movie),
#  The Bling Ring (Movie),
#  The History of Future Folk (Movie),
#  The Legend of Bhagat Singh (Movie),
#  The Magic School Bus Rides Again In the Zone (Movie),
#  The Queen (Movie),
#  The Ring (Movie),
#  The Royal Bengal Tiger (Movie),
#  Time Out (Movie),
#  Time Please (Movie),
#  Time Share (Movie),
#  Time to Hunt (Movie),
#  Time Trap (Movie),
#  Too Handsome to Handle (Movie),
#  Welcome to Monster High: The Origin Story (Movie),
#  When We First Met (Movie),
#  Yes or No (Movie),
#  A Princess for Christmas (Movie),
#  A Sort of Family (Movie),
#  Abdullah, The Final Witness (Movie),
#  Acapulco La vida va (Movie),
#  American Honey (Movie),
#  Baaghi (Movie),
#  Baby Dolls (Movie),
#  Barbie: A Fairy Secret (Movie),
#  Boy and the World (Movie),
#  Bye Bye London (Movie),
#  Carriers (Movie),
#  Chalay Thay Saath (Movie),
#  Chhota Bheem Ka Romani Adventure (Movie),
#  China Salesman (Movie),
#  Chitty Chitty Bang Bang (Movie),
#  Eat Pray Love (Movie),
#  Expedition Happiness (Movie),
#  Follow Me (Movie),
#  French Toast (Movie),
#  Homeland (Movie),
#  Honeymoon Travels Pvt. Ltd. (Movie),
#  Ip Man 4: The Finale (Movie),
#  Jalpari: The Desert Mermaid (Movie),
#  Junebug (Movie),
#  King of Peking (Movie),
#  La Coppia dei Campioni (Movie),
#  Last Ferry (Movie),
#  Mary and the Witch's Flower (Movie),
#  Mehandi Circus (Movie),
#  Menahi (Movie),
#  Merantau (Movie),
#  Michael Lost and Found (Movie),
#  Pope Francis: A Man of His Word (Movie),
#  Ramen Shop (Movie),
#  Roped (Movie),
#  Rumor Has It (Movie),
#  Sara's Notebook (Movie),
#  Sardaarji 2 (Movie),
#  Seoul Searching (Movie),
#  Shine Your Eyes (Movie),
#  Shuddhi (Movie),
#  Simon Killer (Movie),
#  Singapore (Movie),
#  Skin (Movie),
#  Super Nani (Movie),
#  Surat Dari Praha (Movie),
#  Tahaan (Movie),
#  The Burial of Kojo (Movie),
#  The Desert Bride (Movie),
#  The Foreigner (Movie),
#  The Jungle School (Movie),
#  The Last Shaman (Movie),
#  The Lighthouse of the Orcas (Movie),
#  The Mars Generation (Movie),
#  The Maus (Movie),
#  The Ottoman Lieutenant (Movie),
#  The Trader (Sovdagari) (Movie),
#  Thi Mai (Movie),
#  Travel Mates 2 (Movie),
#  True: Rainbow Rescue (Movie),
#  Un plus une (Movie),
#  Under an Arctic Sky (Movie),
#  Under the Eiffel Tower (Movie),
#  A Haunted House (Movie),
#  A Mission in an Old Movie (Movie),
#  A Scandall (Movie),
#  A Separation (Movie),
#  A Shaun the Sheep Movie: Farmageddon (Movie),
#  Ainu Mosir (Movie),
#  Animas (Movie),
#  Ascharyachakit! (Movie),
#  Battle (Movie),
#  Bean: The Ultimate Disaster Movie (Movie),
#  Bee Movie (Movie),
#  Billu (Movie),
#  Blockbuster (Movie),
#  Bobbleheads The Movie (Movie),
#  Bratz: The Movie (Movie),
#  Buddies (Movie),
#  Dear Dad (Movie),
#  Dear Dracula (Movie),
#  Dear Ex (Movie),
#  Dhoondte Reh Jaoge (Movie),
#  Double Dad (Movie),
#  Escape from the "Liberty" Cinema (Movie),
#  Filosofi Kopi The Movie (Movie),
#  GO! The Unforgettable Party (Movie),
#  Gumrah (Movie),
#  Hey Arnold! The Jungle Movie (Movie),
#  High & Low The Movie (Movie),
#  High & Low The Movie 2 / End of Sky (Movie),
#  High & Low The Movie 3 / Final Mission (Movie),
#  Inuyasha the Movie - L'isola del fuoco scarlatto (Movie),
#  Inuyasha the Movie - La spada del dominatore del mondo (Movie),
#  InuYasha: The Movie 2: The Castle Beyond the Looking Glass (Movie),
#  Little Men (Movie),
#  Masameer - The Movie (Movie),
#  Monkey Up (Movie),
#  Movie 43 (Movie),
#  Mr. Chandramouli (Movie),
#  My Babysitter's a Vampire: The Movie (Movie),
#  My Step Dad: The Hippie (Movie),
#  My Week with Marilyn (Movie),
#  Naruto Shippûden the Movie: Bonds (Movie),
#  Naruto Shippûden the Movie: The Will of Fire (Movie),
#  Naruto Shippuden: The Movie (Movie),
#  Naruto Shippuden: The Movie: The Lost Tower (Movie),
#  Naruto the Movie 2: Legend of the Stone of Gelel (Movie),
#  Naruto the Movie 3: Guardians of the Crescent Moon Kingdom (Movie),
#  Naruto the Movie: Ninja Clash in the Land of Snow (Movie),
#  Penguins of Madagascar: The Movie (Movie),
#  Pocoyo Halloween: Spooky Movies (Movie),
#  Pokémon the Movie: I Choose You! (Movie),
#  Pokémon the Movie: Power of Us (Movie),
#  Ragini MMS 2 (Movie),
#  Rugrats in Paris: The Movie (Movie),
#  Sad Hill Unearthed (Movie),
#  Scary Movie (Movie),
#  Scream 2 (Movie),
#  Sex and the City: The Movie (Movie),
#  Shopkins: Chef Club (Movie),
#  Shopkins: Wild (Movie),
#  Shrek the Musical (Movie),
#  Si Doel the Movie (Movie),
#  Si Doel the Movie 2 (Movie),
#  Si Doel the Movie 3 (Movie),
#  Sky Tour: The Movie (Movie),
#  Snow Day (Movie),
#  Swearnet: The Movie (Movie),
#  Tarzan 2 (Movie),
#  Tayo the Little Bus Movie: Mission Ace (Movie),
#  The Angry Birds Movie 2 (Movie),
#  The App (Movie),
#  The Day of the Lord (Movie),
#  The Lovers and the Despot (Movie),
#  The Road to El Camino: Behind the Scenes of El Camino: A Breaking Bad Movie (Movie),
#  The Rugrats Movie (Movie),
#  The Seven Deadly Sins the Movie: Prisoners of the Sky (Movie),
#  Trailer Park Boys: The Movie (Movie),
#  Train to Busan (Movie),
#  Up North (Movie),
#  Very Big Shot (Movie),
#  What a Girl Wants (Movie),
#  You've Got This (Movie),
#  Zaki Chan (Movie),
#  Agatha and the Truth of Murder (Movie),
#  Angel Has Fallen (Movie),
#  Charlie's Angels (Movie),
#  El Camino Christmas (Movie),
#  Eric ldle's What About Dick? (Movie),
#  Extreme Engagement (TV Show),
#  Flash of Genius (Movie),
#  Hamburger Hill (Movie),
#  I Think You Should Leave with Tim Robinson (TV Show),
#  Jack Whitehall: Christmas with My Father (Movie),
#  Kevin Hart: Laugh at My Pain (Movie),
#  Kevin Hart: Let Me Explain (Movie),
#  Kill the Messenger (Movie),
#  Lawless (Movie),
#  Lincoln (Movie),
#  Love, Death & Robots (TV Show),
#  Making The Witcher (Movie),
#  Mean Girls 2 (Movie),
#  Mystic River (Movie),
#  One Last Thing (Movie),
#  Raiders!: The Story of the Greatest Fan Film Ever Made (Movie),
#  Sniper: Special Ops (Movie),
#  The Ballad of Buster Scruggs (Movie),
#  The Con Is On (Movie),
#  The Hateful Eight (Movie),
#  The Men Who Stare at Goats (Movie),
#  V for Vendetta (Movie),
#  30 Minutes or Less (Movie),
#  Adam Devine: Best Time of Our Lives (Movie),
#  Alex Fernández: The Best Comedian in the World (Movie),
#  Always a Witch (TV Show),
#  American Son (Movie),
#  Arsenio Hall: Smart & Classy (Movie),
#  Big Time (Movie),
#  Chris Tucker Live (Movie),
#  Coffee & Kareem (Movie),
#  Demetri Martin: Live (At the Time) (Movie),
#  Deon Cole: Cole Hearted (Movie),
#  Double Jeopardy (Movie),
#  Dragonheart (Movie),
#  Erased (TV Show),
#  Fernando Sanjiao: Hombre (Movie),
#  Genius of the Ancient World (TV Show),
#  Ghosts of Sugar Land (Movie),
#  How to Be a Player (Movie),
#  I'm Brent Morin (Movie),
#  Jen Kirkman: Just Keep Livin’? (Movie),
#  Jenny Slate: Stage Fright (Movie),
#  Jerry Seinfeld: I'm Telling You for the Last Time (Movie),
#  Joe Rogan: Strange Times (Movie),
#  John Mulaney: The Comeback Kid (Movie),
#  Justin Time (TV Show),
#  K-19: The Widowmaker (Movie),
#  Katherine Ryan: In Trouble (Movie),
#  Knowing (Movie),
#  LA 92 (Movie),
#  Leslie Jones: Time Machine (Movie),
#  Marc Maron: End Times Fun (Movie),
#  Michael McIntyre: Showman (Movie),
#  NOVA: Building Chernobyl's MegaTomb (Movie),
#  One More Time (TV Show),
#  Playing for Time (Movie),
#  Point Blank (Movie),
#  Rhyme Time Town Singalongs (TV Show),
#  Rogue Warfare: The Hunt (Movie),
#  Rory Scovel Tries Stand-Up for the First Time (Movie),
#  Sparkle (Movie),
#  The Devil All The Time (Movie),
#  The Movies That Made Us (TV Show),
#  The Pursuit (Movie),
#  The Pursuit of Happyness (Movie),
#  The Unknown Known (Movie),
#  Tomorrow with You (TV Show),
#  14 Minutes from Earth (Movie),
#  Django Unchained (Movie),
#  Edoardo Ferrario: Temi Caldi (Movie),
#  Figures of Speech (Movie),
#  Francesco De Carlo: Cose di Questo Mondo (Movie),
#  Iliza Shlesinger: Elder Millennial (Movie),
#  Internet Famous (Movie),
#  Jack Whitehall: Travels with My Father (TV Show),
#  Léa & I (Movie),
#  Lady Bloodfight (Movie),
#  Mo Amer: The Vagabond (Movie),
#  Monty Python: Live at The Hollywood Bowl (Movie),
#  Nate Bargatze: The Tennessee Kid (Movie),
#  Prospect (Movie),
#  Quigley Down Under (Movie),
#  Refugee (Movie),
#  Romeo Ranjha (Movie),
#  Sam Jay: 3 In The Morning (Movie),
#  The Brothers Grimm (Movie),
#  The Pirates of Somalia (Movie),
#  The Sea of Trees (Movie),
#  Vir Das: Losing It (Movie),
#  7:19 (Movie),
#  23:59 (Movie),
#  9 (Movie),
#  122 (Movie),
#  706 (Movie),
#  1920 (Movie),
#  2,215 (Movie),
#  3022 (Movie),
#  Oct-01 (Movie),
#  15-Aug (Movie),
#  '89 (Movie),
#  ​​Kuch Bheege Alfaaz (Movie),
#  ​Goli Soda 2 (Movie),
#  ​Maj Rati ​​Keteki (Movie),
#  ​Mayurakshi (Movie),
#  #Alive (Movie),
#  #AnneFrank - Parallel Stories (Movie),
#  #cats_the_mewvie (Movie),
#  #FriendButMarried (Movie),
#  #FriendButMarried 2 (Movie),
#  #Roxy (Movie),
#  #Rucker50 (Movie),
#  #Selfie (Movie),
#  #Selfie 69 (Movie),
#  ¡Ay, mi madre! (Movie),
#  Çarsi Pazar (Movie),
#  Ég man þig (Movie),
#  Òlòtūré (Movie),
#  1 Chance 2 Dance (Movie),
#  10 Days in Sun City (Movie),
#  10 jours en or (Movie),
#  100 Days Of Solitude (Movie),
#  100 Meters (Movie),
#  100 Things to do Before High School (Movie),
#  100% Halal (Movie),
#  1000 Rupee Note (Movie),
#  12 ROUND GUN (Movie),
#  13 Cameras (Movie),
#  13 Sins (Movie),
#  13TH: A Conversation with Oprah Winfrey & Ava DuVernay (Movie),
#  14 Blades (Movie),
#  14 Cameras (Movie),
#  18 Presents (Movie),
#  1898: Our Last Men in the Philippines (Movie),
#  1BR (Movie),
#  1st Summoning (Movie),
#  2 Alone in Paris (Movie),
#  2 States (Movie),
#  2015 Dream Concert (Movie),
#  20th Century Women (Movie),
#  2307: Winter's Dream (Movie),
#  25 Kille (Movie),
#  26 Years (Movie),
#  27, el club de los malditos (Movie),
#  3 Deewarein (Movie),
#  3 Generations (Movie),
#  3 Heroines (Movie),
#  3 Idiots (Movie),
#  30 Days of Luxury (Movie),
#  300 Miles to Heaven (Movie),
#  365 Days (Movie),
#  37 Seconds (Movie),
#  40 Sticks (Movie),
#  48 Christmas Wishes (Movie),
#  4L (Movie),
#  4th Man Out (Movie),
#  4th Republic (Movie),
#  5 Cowok Jagoan (Movie),
#  5 Flights Up (Movie),
#  5 Star Christmas (Movie),
#  5 to 7 (Movie),
#  50 First Dates (Movie),
#  50/50 (Movie),
#  5CM (Movie),
#  5Gang (Movie),
#  6 Years (Movie),
#  6-5=2 (Movie),
#  68 Kill (Movie),
#  7 años (Movie),
#  7 Din Mohabbat In (Movie),
#  7 Khoon Maaf (Movie),
#  90 ML (Movie),
#  A 2nd Chance (Movie),
#  A 3 Minute Hug (Movie),
#  A Babysitter's Guide to Monster Hunting (Movie),
#  A Beautiful Life (Movie),
#  A Billion Colour Story (Movie),
#  A Bridge Too Far (Movie),
#  A California Christmas (Movie),
#  A Champion Heart (Movie),
#  A Chaster Marriage (Movie),
#  A Choo (Movie),
#  A Christmas Catch (Movie),
#  A Christmas Prince (Movie),
#  A Christmas Prince: The Royal Baby (Movie),
#  A Christmas Prince: The Royal Wedding (Movie),
#  A Christmas Special: Miraculous: Tales of Ladybug & Cat Noir (Movie),
#  A Cinderella Story (Movie),
#  A Cinderella Story: Christmas Wish (Movie),
#  A Clockwork Orange (Movie),
#  A Dangerous Woman (Movie),
#  A Fairly Odd Summer (Movie),
#  A Family Affair (Movie),
#  A Family Reunion Christmas (Movie),
#  A Flying Jatt (Movie),
#  A Fortunate Man (Movie),
#  A Ghost Story (Movie),
#  A Glimpse Inside the Mind of Charles Swan III (Movie),
#  A Go! Go! Cory Carson Christmas (Movie),
#  A Go! Go! Cory Carson Halloween (Movie),
#  A Go! Go! Cory Carson Summer Camp (Movie),
#  A Haunting at Silver Falls: The Return (Movie),
#  A Heavy Heart (Movie),
#  A Holiday Engagement (Movie),
#  A Home with A View (Movie),
#  A Kid from Coney Island (Movie),
#  A Land Imagined (Movie),
#  A Life of Speed: The Juan Manuel Fangio Story (Movie),
#  A Little Chaos (Movie),
#  A Love Story (Movie),
#  A Mighty Team (Movie),
#  A new Capitalism (Movie),
#  A New York Christmas Wedding (Movie),
#  A Night at the Roxbury (Movie),
#  A Noble Intention (Movie),
#  A Perfect Ending (Movie),
#  A Perfect Man (Movie),
#  A Remarkable Tale (Movie),
#  A Second Chance (Movie),
#  A Serious Man (Movie),
#  A Silent Voice (Movie),
#  A Single Man (Movie),
#  A Sort of Homecoming (Movie),
#  A StoryBots Christmas (Movie),
#  A Sun (Movie),
#  A Tale of Love and Darkness (Movie),
#  A Tale of Two Kitchens (Movie),
#  A Thin Line Between Love & Hate (Movie),
#  A Trash Truck Christmas (Movie),
#  A Trip to Jamaica (Movie),
#  A truthful Mother (Movie),
#  A Twelve Year Night (Movie),
#  A Very Country Christmas (Movie),
#  A Very Special Love (Movie),
#  A Walk to Remember (Movie),
#  A Wednesday (Movie),
#  A Whisker Away (Movie),
#  A Witches' Ball (Movie),
#  A Yellow Bird (Movie),
#  A.M.I. (Movie),
#  A.X.L. (Movie),
#  Aşk Tesadüfleri Sever (Movie),
#  Aadu 2 (Movie),
#  Aagey Se Right (Movie),
#  Aajcha Divas Majha (Movie),
#  Aakhri Adaalat (Movie),
#  Aalorukkam (Movie),
#  Aamir (Movie),
#  Aapla Manus (Movie),
#  Aarakshan (Movie),
#  Aashayein (Movie),
#  Aashik Awara (Movie),
#  Aata Pita (Movie),
#  Aaviri (Movie),
#  ABCD 2 (Movie),
#  ABCD: Any Body Can Dance (Movie),
#  Abdo Mota (Movie),
#  Abhinetri (Movie),
#  Abominable Christmas (Movie),
#  About a Boy (Movie),
#  Abzurdah (Movie),
#  Accident (Movie),
#  Across The Line (Movie),
#  Across the Universe (Movie),
#  Act of Vengeance (Movie),
#  Acts of Vengeance (Movie),
#  Adú (Movie),
#  Addicted to Life (Movie),
#  Adhugo (Movie),
#  Aditi Mittal: Things They Wouldn't Let Me Say (Movie),
#  Adore (Movie),
#  Adrift (Movie),
#  Adrishya (Movie),
#  Advantageous (Movie),
#  Aerials (Movie),
#  After (Movie),
#  After the Raid (Movie),
#  After We Collided (Movie),
#  Afterschool (Movie),
#  Aftershock (Movie),
#  Aggretsuko: We Wish You a Metal Christmas (Movie),
#  Agneepath (Movie),
#  Agyaat (Movie),
#  Ahista Ahista (Movie),
#  Airplane Mode (Movie),
#  Aisa Yeh Jahaan (Movie),
#  Aitraaz (Movie),
#  Aiyaary (Movie),
#  Aiyyaa (Movie),
#  Ajab Prem Ki Ghazab Kahani (Movie),
#  Ajji (Movie),
#  Al acecho (Movie),
#  Alakada Reloaded (Movie),
#  Alarmoty in the Land of Fire (Movie),
#  Alaska Is a Drag (Movie),
#  Albert Pinto Ko Gussa Kyun Aata Hai? (Movie),
#  Albion: The Enchanted Stallion (Movie),
#  Alejandro Sanz: What I Was Is What I Am (Movie),
#  Alelí (Movie),
#  Alex Strangelove (Movie),
#  Alexandria ... Why? (Movie),
#  Alexandria: Again and Forever (Movie),
#  Alexis Viera: A Story of Surviving (Movie),
#  Ali & Alia (Movie),
#  Ali Baba ve 7 Cüceler (Movie),
#  Ali's Wedding (Movie),
#  Alias JJ, la celebridad del mal (Movie),
#  Alibaba Aur 40 Chor (Movie),
#  Alice Doesn't Live Here Anymore (Movie),
#  Alice Junior (Movie),
#  Alien Xmas (Movie),
#  Aliens Ate My Homework (Movie),
#  All About Love (Movie),
#  All About Nina (Movie),
#  All Because of You (Movie),
#  All Day and a Night (Movie),
#  All Dogs Go to Heaven (Movie),
#  All Good Ones Get Away (Movie),
#  All Hallows' Eve (Movie),
#  All In My Family (Movie),
#  All Light Will End (Movie),
#  All of You (Movie),
#  All the Boys Love Mandy Lane (Movie),
#  All The Bright Places (Movie),
#  All the Freckles in the World (Movie),
#  All The Reasons To Forget (Movie),
#  All's Well, End's Well (2009) (Movie),
#  Alles ist gut (Movie),
#  AllI Wish (Movie),
#  Almost Love (Movie),
#  Alone/Together (Movie),
#  Alpha and Omega 2: A Howl-iday Adventure (Movie),
#  Alpha and Omega: The Legend of the Saw Tooth Cave (Movie),
#  Altered Carbon: Resleeved (Movie),
#  Always a Bridesmaid (Movie),
#  Always Be My Maybe (Movie),
#  Amandla! A Revolution in Four Part Harmony (Movie),
#  Amar (Movie),
#  Amar Akbar & Tony (Movie),
#  Amar Akbar Anthony (Movie),
#  Amar's Hands (Movie),
#  Amateur (Movie),
#  American Psycho (Movie),
#  Among Family (Movie),
#  Amrapali (Movie),
#  Amy (Movie),
#  An American in Madras (Movie),
#  An American Tail (Movie),
#  An American Tail: Fievel Goes West (Movie),
#  An American Tail: The Mystery of the Night Monster (Movie),
#  An American Tail: The Treasures of Manhattan Island (Movie),
#  An Easy Girl (Movie),
#  An Egyptian Story (Movie),
#  An Evening with Beverly Luff Linn (Movie),
#  An Hour and a Half (Movie),
#  An Unremarkable Christmas (Movie),
#  An Upper Egyptian (Movie),
#  Ana e Vitória (Movie),
#  Anaamika (Movie),
#  Anarkali of Aarah (Movie),
#  Anchor and Hope (Movie),
#  Anchor Baby (Movie),
#  And Breathe Normally (Movie),
#  Andaleeb El Dokki (Movie),
#  Andaz Apna Apna (Movie),
#  Andhadhun (Movie),
#  Andhaghaaram (Movie),
#  Andhakaaram (Movie),
#  André & his olive tree (Movie),
#  Anelka: Misunderstood (Movie),
#  Angel Eyes (Movie),
#  Angela's Christmas (Movie),
#  Angry Indian Goddesses (Movie),
#  Ani... Dr. Kashinath Ghanekar (Movie),
#  ANIMA (Movie),
#  Animal Crackers (Movie),
#  Animal World (Movie),
#  Anjaan (Movie),
#  Ankhon Dekhi (Movie),
#  Ankur Arora Murder Case (Movie),
#  Annabelle Hooper and the Ghosts of Nantucket (Movie),
#  Another Forever (Movie),
#  Antar: Son of Shadad (Movie),
#  Antariksha Ke Rakhwale (Movie),
#  Anthony Kaun Hai? (Movie),
#  Antidote (Movie),
#  Antoine Griezmann: The Making of a Legend (Movie),
#  Anwar (Movie),
#  Apaharan (Movie),
#  Apollo 18 (Movie),
#  Apostle (Movie),
#  April and the Extraordinary World (Movie),
#  Arès (Movie),
#  Aram, Aram (Movie),
#  Arctic Dogs (Movie),
#  Arctic Heart (Movie),
#  Are We Done Yet? (Movie),
#  Arisan 2 (Movie),
#  Arjun: The Warrior Prince (Movie),
#  Arthur (Movie),
#  Arthur Christmas (Movie),
#  Article 15 (Movie),
#  Aruna & Her Palate (Movie),
#  As Above, So Below (Movie),
#  As Good as It Gets (Movie),
#  Asees (Movie),
#  Asoka (Movie),
#  Asphalt Burning (Movie),
#  Assimilate (Movie),
#  Asu Mare 2 (Movie),
#  Asura Guru (Movie),
#  Asura: The City of Madness (Movie),
#  At All Costs (Movie),
#  Athlete A (Movie),
#  Atlantics (Movie),
#  ATM (Movie),
#  Attacking the Devil: Harold Evans and the Last Nazi War Crime (Movie),
#  Attitude Test (Movie),
#  Aurora (Movie),
#  Autohead (Movie),
#  Ave Maryam (Movie),
#  Await Further Instructions (Movie),
#  Axone (Movie),
#  Ayana (Movie),
#  Ayotzinapa, el paso de la tortuga (Movie),
#  Azali (Movie),
#  Azhar (Movie),
#  B.A. Pass (Movie),
#  B.A. Pass 2 (Movie),
#  Baadshaho (Movie),
#  Baahubali 2: The Conclusion (Hindi Version) (Movie),
#  Baahubali 2: The Conclusion (Malayalam Version) (Movie),
#  Baahubali 2: The Conclusion (Tamil Version) (Movie),
#  Baahubali: The Beginning (English Version) (Movie),
#  Baahubali: The Beginning (Hindi Version) (Movie),
#  Baahubali: The Beginning (Malayalam Version) (Movie),
#  Baahubali: The Beginning (Tamil Version) (Movie),
#  Baazaar (Movie),
#  Babam ve Oğlum (Movie),
#  Babamın Ceketi (Movie),
#  Babel (Movie),
#  Baby Mamas (Movie),
#  Bachelor Girls (Movie),
#  Back and Forth (Movie),
#  Back of the Net (Movie),
#  Back to School (Movie),
#  Back to the 90s (Movie),
#  Backcountry (Movie),
#  Backfire (Movie),
#  Bad Day for the Cut (Movie),
#  Bad Genius (Movie),
#  Bad Seeds (Movie),
#  Badha (Movie),
#  Badla (Movie),
#  Balto (Movie),
#  Balto 2: Wolf Quest (Movie),
#  Balto 3: Wings of Change (Movie),
#  Balu Mahi (Movie),
#  Bana Masal Anlatma (Movie),
#  Banana Island Ghost (Movie),
#  Banana Split (Movie),
#  Band Aid (Movie),
#  Band of Robbers (Movie),
#  Bandie (Movie),
#  Bang Rajan 2 (Movie),
#  Bangistan (Movie),
#  Bangkok Hell (Movie),
#  Bangkok Traffic (Love) Story (Movie),
#  Barça Dreams (Movie),
#  Barah Aana (Movie),
#  Barakah Meets Barakah (Movie),
#  Barbecue (Movie),
#  Barbie & Her Sisters in a Pony Tale (Movie),
#  Barbie Dolphin Magic (Movie),
#  Barbie in A Mermaid Tale (Movie),
#  Barbie in Princess Power (Movie),
#  Barbie in Rock 'N Royals (Movie),
#  Barbie Princess Adventure (Movie),
#  Barbie Star Light Adventure (Movie),
#  Barbie: Princess Charm School (Movie),
#  Barbie: Spy Squad (Movie),
#  Barbie: The Princess & the Popstar (Movie),
#  Barbie: Video Game Hero (Movie),
#  Barcelona: A Love Untold (Movie),
#  Bareilly Ki Barfi (Movie),
#  Barfi! (Movie),
#  Barrio Universitario (Movie),
#  Barsaat (Movie),
#  BASEketball (Movie),
#  Basic Instinct (Movie),
#  Bathinda Express (Movie),
#  Battle Drone (Movie),
#  Bawarchi (Movie),
#  Baxu and the Giants (Movie),
#  Bayonet (Movie),
#  Bazaar (Movie),
#  Be Somebody (Movie),
#  Beak & Brain: Genius Birds From Down Under (Movie),
#  Beary Tales (Movie),
#  Beasts of No Nation (Movie),
#  Beat Bugs: All Together Now (Movie),
#  Beats (Movie),
#  Beauties of the Night (Movie),
#  Beauty and the Bestie (Movie),
#  Beavis and Butt-head Do America (Movie),
#  Because of Soccer (Movie),
#  Because We're Heading Out (Movie),
#  Becoming Jane (Movie),
#  Been So Long (Movie),
#  Before I Fall (Movie),
#  Before I Wake (Movie),
#  Before the Summer Crowds (Movie),
#  Behind "The Cove": The Quiet Japanese Speak Out (Movie),
#  Behind the Curtain: Todrick Hall (Movie),
#  Beiimaan Love (Movie),
#  Being AP (Movie),
#  Being Mrs Elliot (Movie),
#  Beirut Oh Beirut (Movie),
#  Belgica (Movie),
#  Belief: The Possession of Janet Moses (Movie),
#  Belmonte (Movie),
#  Below Her Mouth (Movie),
#  Benchwarmers 2: Breaking Balls (Movie),
#  Beneath the Leaves (Movie),
#  Benji (Movie),
#  Benji: Off the Leash (Movie),
#  Benji's Very Own Christmas Story (Movie),
#  Bennett's War (Movie),
#  Berlin Calling (Movie),
#  Berlin Kaplani (Movie),
#  Berlin Syndrome (Movie),
#  Berlin, Berlin: Lolle on the Run (Movie),
#  Berlin, I Love You (Movie),
#  Berserk: The Golden Age Arc I - The Egg of the King (Movie),
#  Berserk: The Golden Age Arc II - The Battle for Doldrey (Movie),
#  Berserk: The Golden Age Arc III - The Advent (Movie),
#  Bert Kreischer: Hey Big Boy (Movie),
#  Best Neighbors (Movie),
#  Best Wishes, Warmest Regards: A Schitt's Creek Farewell (Movie),
#  Bethany Hamilton: Unstoppable (Movie),
#  Between Maybes (Movie),
#  Between Two Ferns: The Movie (Movie),
#  Bewafaa (Movie),
#  Bewildered Bolbol (Movie),
#  Beynelmilel (Movie),
#  Beyond All Boundaries (Movie),
#  Beyond the Boundary: ICC Women's T20 World Cup Australia 2020 (Movie),
#  Beyond the Clouds (Movie),
#  Bhagam Bhag (Movie),
#  Bhai: Vyakti Ki Valli - Poorvardha (Movie),
#  Bhai: Vyakti Ki Valli - Uttarardh (Movie),
#  Bhaji In Problem (Movie),
#  Bhangra Paa Le (Movie),
#  Bhasmasur (Movie),
#  Bhavesh Joshi Superhero (Movie),
#  Bheemayan (Movie),
#  Bheeshma (Movie),
#  Bhool Bhulaiyaa (Movie),
#  Bhoot (Movie),
#  Bhouri (Movie),
#  Bibi & Tina (Movie),
#  Bibi & Tina II (Movie),
#  Bibi & Tina: Girls Versus Boys (Movie),
#  Bibi & Tina: Tohuwabohu Total (Movie),
#  Big Fat Liar (Movie),
#  Big Stone Gap (Movie),
#  Bigflo & Oli: Hip Hop Frenzy (Movie),
#  Bigger Fatter Liar (Movie),
#  Billy Elliot (Movie),
#  Bilu Rakkhosh (Movie),
#  Bioscope (Movie),
#  Bir Baba Hindu (Movie),
#  Birders (Movie),
#  Birdshot (Movie),
#  Birthmarked (Movie),
#  Bitch (Movie),
#  Bitcoin Heist (Movie),
#  Bittersweet (Movie),
#  Bittoo Boss (Movie),
#  Black (Movie),
#  Black '47 (Movie),
#  Black Friday (Movie),
#  Black Man White Skin (Movie),
#  Black Mirror: Bandersnatch (Movie),
#  Black Rose (Movie),
#  Black Sea (Movie),
#  Black Snake Moan (Movie),
#  Black Snow (Movie),
#  BLAME! (Movie),
#  Blaze (Movie),
#  Bleach The Movie: Fade to Black (Movie),
#  Bleach the Movie: Hell Verse (Movie),
#  Bleed for This (Movie),
#  Blessed Benefit (Movie),
#  Blind Date (Movie),
#  Blind Detective (Movie),
#  Blitz Patrollie (Movie),
#  Blood Father (Movie),
#  Blood Money (Movie),
#  Blood Will Tell (Movie),
#  Blue Is the Warmest Color (Movie),
#  Blue Jasmine (Movie),
#  Blue Jay (Movie),
#  Blue Ruin (Movie),
#  Blue Valentine (Movie),
#  BluffMaster! (Movie),
#  BNK48: Girls Don't Cry (Movie),
#  Bob's Broken Sleigh (Movie),
#  Bobby (Movie),
#  Bobby Jasoos (Movie),
#  Bodyguard (Movie),
#  Bogda (Movie),
#  Boi (Movie),
#  BoJack Horseman Christmas Special: Sabrina's Christmas Wish (Movie),
#  Bokeh (Movie),
#  Bollywood Calling (Movie),
#  Bolt (Movie),
#  Bomb Scared (Movie),
#  Bombairiya (Movie),
#  Bombay Talkies (Movie),
#  Bon Bini Holland (Movie),
#  Bon Cop, Bad Cop (Movie),
#  Bonnie and Clyde (Movie),
#  Boom (Movie),
#  Born Beautiful (Movie),
#  Born in Gaza (Movie),
#  Born in Syria (Movie),
#  Born Racer (Movie),
#  Born Strong (Movie),
#  Born to Be Free (Movie),
#  Bosta (Movie),
#  Bottom of the World (Movie),
#  Boushkash (Movie),
#  Boy Bye (Movie),
#  Boy Missing (Movie),
#  Brahman Naman (Movie),
#  Brain on Fire (Movie),
#  Brampton's Own (Movie),
#  Brave New Jersey (Movie),
#  Break (Movie),
#  Break Ke Baad (Movie),
#  Break Up 100 (Movie),
#  Breaking Free (Movie),
#  Breaking the Bank (Movie),
#  Breath (Movie),
#  Brick (Movie),
#  Bride For Rent (Movie),
#  Bridezilla (Movie),
#  Brij Mohan Amar Rahe (Movie),
#  Brother (Movie),
#  Brother in Love (Movie),
#  Brotherhood of Blades II: The Infernal Battlefield (Movie),
#  Brothers (Movie),
#  Bruno and Boots: Go Jump in the Pool (Movie),
#  Bruno and Boots: The Wizzle War (Movie),
#  Bruno and Boots: This Can't Be Happening at Macdonald Hall (Movie),
#  Bucket List (Movie),
#  Budapest (Movie),
#  Buddy Thunderstruck: The Maybe Pile (Movie),
#  Budhia Singh: Born to Run (Movie),
#  Buffalo Boys (Movie),
#  Bugs (Movie),
#  Bulbbul (Movie),
#  Bulbul Can Sing (Movie),
#  Bullet Head (Movie),
#  Bullitt County (Movie),
#  Burlesque (Movie),
#  Burn Out (Movie),
#  Burning (Movie),
#  Burning Sands (Movie),
#  Bushwick (Movie),
#  Buster's Mal Heart (Movie),
#  Butterfield 8 (Movie),
#  BuyBust (Movie),
#  Bwakaw (Movie),
#  By the Sea (Movie),
#  Bygones Be Bygones (Movie),
#  Bypass Road (Movie),
#  C Kkompany (Movie),
#  Cézanne et moi (Movie),
#  Cabin Fever (Movie),
#  Cadaver (Movie),
#  Cahaya Dari Timur Beta Maluku (Movie),
#  Caida del Cielo (Movie),
#  Cairo Station (Movie),
#  Cake (Movie),
#  Calendar Girls (Movie),
#  Calibre (Movie),
#  Calico Critters: A Town of Dreams (Movie),
#  Calico Critters: Everyone's Big Dream Flying in the Sky (Movie),
#  Calico Critters: The Treasure of Calico Village (Movie),
#  ...]

# %% [markdown]
# In the case that a word that has no matches, it will be excluded from the search. This stops typos and spelling errors having as much of an effect.

# %%
netflix.search('tyme travel tim')
# Out:
# Excluding 'tyme' from the search as no matches were found
# [Extreme Engagement (TV Show), The Cakemaker (Movie), About Time (Movie)]

# %% [markdown]
# # Task 3
# ## Data analysis task (b)
# ### (a)
# I'm goint to count the words used by year, to see if the topics have changed as time has gone on. I will group the years so that there is a sufficient amount of data.
# Groupings:
# since_2010: 2010 - Presant
# since_2000: 2000 - 2009
# since_1980: 1980 - 1999
# before_1980: 0 - 1980

# %%
netflix_data_2 = netflix_data_raw[['title', 'director', 'cast','release_year', 'country', 'type', 'date_added', 'rating', 'duration', 'listed_in', 'description']]

# %%
def word_count(text, dic):
    words = clean_text(text)

    for word in words:
        if word in dic:
            dic[word] += 1
        else:
            dic[word] = 1
    return(dic)

# %%
since_2010 = {}
since_2000 = {}
since_1980 = {}
before_1980 = {}
for i in range(len(netflix_data_2)):
    if netflix_data_2[['release_year']].iloc[i,0] >= 2010:
        text = netflix_data_2[['description']].iloc[i,0]
        since_2010 = word_count(text, since_2010)
    elif netflix_data_2[['release_year']].iloc[i,0] >= 2000:
        text = netflix_data_2[['description']].iloc[i,0]
        since_2000 = word_count(text, since_2000)
    elif netflix_data_2[['release_year']].iloc[i,0] >= 1980:
        text = netflix_data_2[['description']].iloc[i,0]
        since_1980 = word_count(text, since_1980)
    elif netflix_data_2[['release_year']].iloc[i,0] < 1980:
        text = netflix_data_2[['description']].iloc[i,0]
        before_1980 = word_count(text, before_1980)
    else:
        print(netflix_data_2[['release_year']].iloc[i,0])

# %%
sorted(since_2010.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('life', 603),
#  ('young', 547),
#  ('famili', 528),
#  ('find', 513),
#  ('new', 511),
#  ('friend', 462),
#  ('world', 425),
#  ('love', 415),
#  ('take', 404),
#  ('live', 388),
#  ('man', 388),
#  ('two', 367),
#  ('woman', 357),
#  ('get', 319),
#  ('seri', 312),
#  ('documentari', 298),
#  ('becom', 293),
#  ('help', 279),
#  ('must', 270),
#  ('stori', 258),
#  ('year', 254),
#  ('``', 250),
#  ('home', 242),
#  ('one', 239),
#  ('tri', 236),
#  ('school', 236),
#  ('father', 235),
#  ('mysteri', 216),
#  ('three', 214),
#  ('turn', 213),
#  ('teen', 211),
#  ('murder', 210),
#  ('follow', 210),
#  ('group', 202),
#  ('set', 201),
#  ('forc', 199),
#  ('make', 199),
#  ('struggl', 196),
#  ('learn', 195),
#  ('team', 194),
#  ('save', 192),
#  ('secret', 192),
#  ('girl', 192),
#  ('meet', 185),
#  ('fall', 183),
#  ('special', 182),
#  ('show', 179),
#  ('explor', 178),
#  ('face', 177),
#  ('student', 176),
#  ('mother', 175),
#  ('fight', 171),
#  ('work', 170),
#  ('back', 168),
#  ('power', 168),
#  ('citi', 163),
#  ('high', 163),
#  ('way', 162),
#  ('adventur', 162),
#  ('return', 161),
#  ('son', 161),
#  ('star', 160),
#  ('boy', 160),
#  ('past', 160),
#  ('death', 159),
#  ('daughter', 158),
#  ('discov', 157),
#  ('true', 153),
#  ('investig', 153),
#  ('lead', 151),
#  ('begin', 147),
#  ('crime', 147),
#  ('film', 146),
#  ('four', 146),
#  ('women', 145),
#  ('time', 144),
#  ('brother', 142),
#  ('come', 142),
#  ('battl', 141),
#  ('war', 141),
#  ('wife', 140),
#  ('relationship', 139),
#  ('dream', 138),
#  ('person', 137),
#  ('journey', 137),
#  ('music', 134),
#  ('comedi', 133),
#  ('coupl', 131),
#  ('town', 131),
#  ('comedian', 131),
#  ('best', 130),
#  ('travel', 130),
#  ('share', 129),
#  ('stand-up', 129),
#  ('look', 128),
#  ('search', 125),
#  ('plan', 123),
#  ('behind', 122),
#  ('use', 121),
#  ('join', 118),
#  ('move', 118),
#  ('first', 118),
#  ('bring', 117),
#  ('teenag', 117),
#  ('human', 116),
#  ('career', 115),
#  ('former', 114),
#  ('romanc', 113),
#  ('histori', 113),
#  ('day', 112),
#  ('polic', 112),
#  ('differ', 111),
#  ('leav', 111),
#  ('togeth', 111),
#  ('drug', 111),
#  ('run', 110),
#  ('game', 110),
#  ('celebr', 110),
#  ('cop', 110),
#  ('magic', 110),
#  ('cultur', 109),
#  ('mission', 109),
#  ('base', 108),
#  ('chang', 108),
#  ('anim', 108),
#  ('detect', 106),
#  ('comic', 106),
#  ('polit', 105),
#  ('sister', 104),
#  ('seek', 104),
#  ('start', 104),
#  ('dark', 103),
#  ('old', 103),
#  ('marri', 102),
#  ('husband', 102),
#  ('danger', 102),
#  ('soon', 102),
#  ('go', 102),
#  ('marriag', 100),
#  ('surviv', 100),
#  ('event', 100),
#  ('drama', 99),
#  ('crimin', 96),
#  ('colleg', 96),
#  ('peopl', 95),
#  ('challeng', 95),
#  ('keep', 94),
#  ('villag', 93),
#  ('win', 91),
#  ('evil', 91),
#  ('kid', 91),
#  ('around', 91),
#  ('futur', 90),
#  ('end', 89),
#  ('american', 89),
#  ('social', 88),
#  ('kill', 88),
#  ('hope', 88),
#  ('parent', 88),
#  ('job', 88),
#  ('realiti', 88),
#  ('goe', 87),
#  ('navig', 86),
#  ('offic', 85),
#  ('busi', 85),
#  ('hit', 84),
#  ('test', 84),
#  ('rise', 83),
#  ('bond', 83),
#  ('big', 83),
#  ('stage', 83),
#  ('inspir', 82),
#  ('play', 82),
#  ('agent', 82),
#  ('host', 82),
#  ('killer', 81),
#  ('five', 81),
#  ("n't", 81),
#  ('attempt', 81),
#  ('night', 80),
#  ('threaten', 80),
#  ('path', 80),
#  ('childhood', 80),
#  ('tale', 79),
#  ('earth', 79),
#  ('land', 79),
#  ('embark', 79),
#  ('trip', 79),
#  ('troubl', 79),
#  ('chanc', 78),
#  ('local', 78),
#  ('countri', 78),
#  ('india', 78),
#  ('form', 78),
#  ('determin', 78),
#  ('case', 78),
#  ('friendship', 77),
#  ('artist', 77),
#  ('prison', 77),
#  ('truth', 77),
#  ('band', 77),
#  ('whose', 77),
#  ('competit', 76),
#  ('reveal', 75),
#  ('corrupt', 75),
#  ('spirit', 75),
#  ('experi', 74),
#  ('protect', 74),
#  ('men', 73),
#  ('crew', 73),
#  ('train', 72),
#  ('sex', 72),
#  ('pal', 72),
#  ('rescu', 71),
#  ('york', 71),
#  ('quest', 71),
#  ('real', 71),
#  ('girlfriend', 70),
#  ('decid', 70),
#  ('child', 70),
#  ('transform', 70),
#  ('children', 70),
#  ('uncov', 69),
#  ('race', 69),
#  ('singl', 69),
#  ('perform', 69),
#  ('encount', 68),
#  ('break', 68),
#  ('heart', 68),
#  ('head', 68),
#  ('fun', 68),
#  ('kidnap', 67),
#  ('christma', 67),
#  ('thing', 67),
#  ('everyth', 67),
#  ('miss', 66),
#  ('street', 66),
#  ('gang', 66),
#  ('may', 66),
#  ('interview', 65),
#  ('success', 65),
#  ('put', 65),
#  ('small', 65),
#  ('tv', 65),
#  ('solv', 65),
#  ('reveng', 65),
#  ('writer', 64),
#  ('insid', 64),
#  ('commun', 64),
#  ('aspir', 64),
#  ('hunt', 64),
#  ('wed', 64),
#  ('hous', 63),
#  ('ident', 63),
#  ('filmmak', 63),
#  ('demon', 62),
#  ('wealthi', 62),
#  ('hire', 62),
#  ('talent', 62),
#  ('creat', 61),
#  ('haunt', 60),
#  ('doctor', 60),
#  ('examin', 60),
#  ('captur', 60),
#  ('connect', 60),
#  ('art', 60),
#  ('lose', 59),
#  ('final', 59),
#  ('parti', 59),
#  ('want', 59),
#  ('escap', 58),
#  ('stranger', 58),
#  ('featur', 58),
#  ('icon', 58),
#  ('unexpect', 58),
#  ('need', 58),
#  ('pursu', 58),
#  ('visit', 57),
#  ('apart', 57),
#  ('road', 57),
#  ('grow', 57),
#  ('offer', 57),
#  ('island', 56),
#  ('america', 56),
#  ('brutal', 56),
#  ('passion', 56),
#  ('chef', 56),
#  ('violent', 56),
#  ('london', 56),
#  ('player', 55),
#  ('wild', 55),
#  ('plot', 55),
#  ('date', 55),
#  ('build', 55),
#  ('popular', 55),
#  ('elit', 54),
#  ('desper', 54),
#  ('mumbai', 54),
#  ('memori', 54),
#  ('design', 54),
#  ('romant', 54),
#  ('complic', 54),
#  ('skill', 54),
#  ('name', 54),
#  ('legendari', 54),
#  ('across', 53),
#  ('attack', 53),
#  ('littl', 53),
#  ('die', 53),
#  ('holiday', 53),
#  ('beauti', 53),
#  ('member', 53),
#  ('track', 53),
#  ('nation', 53),
#  ('away', 53),
#  ('see', 53),
#  ('stop', 53),
#  ('bodi', 53),
#  ('compani', 53),
#  ('accid', 52),
#  ('govern', 52),
#  ('order', 52),
#  ('give', 52),
#  ('deal', 52),
#  ('prove', 52),
#  ('mom', 52),
#  ('even', 52),
#  ('car', 52),
#  ('open', 51),
#  ('u.s.', 51),
#  ('director', 51),
#  ('deadli', 51),
#  ('feel', 51),
#  ('actor', 51),
#  ('tell', 51),
#  ('expert', 51),
#  ('like', 50),
#  ('rais', 50),
#  ('monster', 50),
#  ('amid', 50),
#  ('good', 50),
#  ('scientist', 50),
#  ('modern', 50),
#  ('compet', 50),
#  ('decad', 49),
#  ('video', 49),
#  ('disappear', 49),
#  ('right', 49),
#  ('boss', 49),
#  ('suspect', 49),
#  ('teacher', 49),
#  ('includ', 49),
#  ('tour', 49),
#  ('side', 48),
#  ('femal', 48),
#  ('rival', 48),
#  ('last', 48),
#  ('control', 48),
#  ('soccer', 48),
#  ('leader', 48),
#  ('ambiti', 48),
#  ('problem', 48),
#  ('rule', 48),
#  ('charact', 48),
#  ('confront', 47),
#  ('footag', 47),
#  ('journalist', 47),
#  ('call', 47),
#  ('clash', 47),
#  ('scheme', 47),
#  ('indian', 47),
#  ('societi', 46),
#  ('question', 46),
#  ('hometown', 46),
#  ('involv', 46),
#  ('fate', 46),
#  ('tradit', 46),
#  ('mexico', 45),
#  ('king', 45),
#  ('realiz', 45),
#  ('age', 45),
#  ('estrang', 45),
#  ('remot', 45),
#  ('natur', 45),
#  ('sexual', 45),
#  ('partner', 45),
#  ('surpris', 45),
#  ('fame', 45),
#  ('epic', 45),
#  ('univers', 45),
#  ('armi', 44),
#  ('docuseri', 44),
#  ('crush', 44),
#  ('owner', 44),
#  ('gift', 44),
#  ('singer', 44),
#  ('money', 44),
#  ('obsess', 44),
#  ('la', 44),
#  ('wake', 44),
#  ('gener', 44),
#  ('sibl', 44),
#  ('sport', 43),
#  ('supernatur', 43),
#  ('everi', 43),
#  ('place', 43),
#  ('send', 43),
#  ('alien', 43),
#  ('lover', 43),
#  ('six', 43),
#  ('wit', 43),
#  ('lawyer', 43),
#  ('neighbor', 43),
#  ('terrorist', 43),
#  ('planet', 43),
#  ('uniqu', 43),
#  ('enter', 43),
#  ('next', 43),
#  ('rich', 43),
#  ('global', 43),
#  ('stay', 42),
#  ('intim', 42),
#  ('reunit', 42),
#  ('along', 42),
#  ('top', 42),
#  ('danc', 42),
#  ('unlik', 42),
#  ('belov', 42),
#  ('famou', 42),
#  ('shock', 41),
#  ('justic', 41),
#  ('cross', 41),
#  ('chronicl', 41),
#  ('long', 41),
#  ('food', 41),
#  ('creatur', 41),
#  ('arriv', 41),
#  ('anoth', 41),
#  ('talk', 41),
#  ('light', 41),
#  ('trap', 40),
#  ('driver', 40),
#  ('politician', 40),
#  ('oper', 40),
#  ('target', 40),
#  ('expos', 40),
#  ('south', 40),
#  ('strang', 40),
#  ('care', 40),
#  ('caught', 40),
#  ('dad', 40),
#  ('steal', 40),
#  ('sinist', 40),
#  ('classic', 40),
#  ('law', 39),
#  ('cast', 39),
#  ('left', 39),
#  ('babi', 39),
#  ('could', 39),
#  ('impact', 39),
#  ('risk', 39),
#  ('widow', 39),
#  ('fail', 39),
#  ('rock', 38),
#  ('space', 38),
#  ('resid', 38),
#  ('media', 38),
#  ('dog', 38),
#  ('short', 38),
#  ('lesson', 38),
#  ('wrong', 38),
#  ('serial', 38),
#  ('enemi', 38),
#  ('lost', 38),
#  ('known', 38),
#  ('emot', 38),
#  ('club', 38),
#  ('humor', 38),
#  ('deep', 37),
#  ('summer', 37),
#  ('spend', 37),
#  ('boyfriend', 37),
#  ('victim', 37),
#  ('musician', 37),
#  ('crisi', 37),
#  ('intern', 37),
#  ('hand', 37),
#  ('ghost', 37),
#  ('tackl', 37),
#  ('extraordinari', 37),
#  ('book', 37),
#  ('twist', 37),
#  ('deliv', 37),
#  ('dramat', 37),
#  ('reflect', 37),
#  ('soldier', 36),
#  ('histor', 36),
#  ('mind', 36),
#  ('report', 36),
#  ('fashion', 36),
#  ('angel', 36),
#  ('fear', 36),
#  ('act', 36),
#  ('hotel', 36),
#  ('mean', 36),
#  ('sent', 36),
#  ('figur', 36),
#  ('guest', 36),
#  ('creativ', 36),
#  ('master', 36),
#  ('recruit', 35),
#  ('medic', 35),
#  ('much', 35),
#  ('onlin', 35),
#  ('spain', 35),
#  ('lo', 35),
#  ('commit', 35),
#  ('trace', 35),
#  ('major', 35),
#  ('pop', 35),
#  ('hilari', 35),
#  ('hero', 35),
#  ('eccentr', 35),
#  ('origin', 35),
#  ('terrifi', 34),
#  ('conspiraci', 34),
#  ('cat', 34),
#  ('profession', 34),
#  ('activist', 34),
#  ('buddi', 34),
#  ('center', 34),
#  ('british', 34),
#  ('movi', 34),
#  ('song', 34),
#  ('serv', 34),
#  ('abus', 34),
#  ('pari', 34),
#  ('ii', 34),
#  ('tragedi', 33),
#  ('unit', 33),
#  ('collect', 33),
#  ('photograph', 33),
#  ('hidden', 33),
#  ('unravel', 33),
#  ('tragic', 33),
#  ('issu', 33),
#  ('vacat', 33),
#  ('horror', 33),
#  ('convict', 33),
#  ('worker', 33),
#  ('engin', 33),
#  ('kingdom', 33),
#  ('empir', 33),
#  ('class', 33),
#  ('answer', 33),
#  ('bad', 33),
#  ('present', 33),
#  ('color', 33),
#  ('gay', 33),
#  ('champion', 33),
#  ('pair', 33),
#  ('dead', 32),
#  ('separ', 32),
#  ('athlet', 32),
#  ('spark', 32),
#  ('industri', 32),
#  ('violenc', 32),
#  ('dancer', 32),
#  ('later', 32),
#  ('suicid', 32),
#  ('classmat', 32),
#  ('stand', 32),
#  ('1980', 32),
#  ('divorc', 32),
#  ('manag', 32),
#  ('black', 32),
#  ('superhero', 32),
#  ('seem', 32),
#  ('accus', 32),
#  ('fighter', 32),
#  ('happen', 32),
#  ('still', 32),
#  ('loss', 32),
#  ('eye', 32),
#  ('ancient', 32),
#  ('camp', 31),
#  ('develop', 31),
#  ('biggest', 31),
#  ('prize', 31),
#  ('record', 31),
#  ('bank', 31),
#  ('heist', 31),
#  ('affair', 31),
#  ('controversi', 31),
#  ('reconnect', 31),
#  ('civil', 31),
#  ('presid', 31),
#  ('step', 31),
#  ('notori', 31),
#  ('veteran', 31),
#  ('assassin', 30),
#  ('despit', 30),
#  ('ruthless', 30),
#  ('happi', 30),
#  ('betray', 30),
#  ('engag', 30),
#  ('lord', 30),
#  ('ill', 30),
#  ('hunter', 30),
#  ('queen', 30),
#  ('full', 30),
#  ('1970', 30),
#  ('adult', 30),
#  ('funni', 30),
#  ('french', 30),
#  ('neighborhood', 30),
#  ('park', 30),
#  ('retir', 30),
#  ('befriend', 30),
#  ('small-town', 30),
#  ('survivor', 29),
#  ('farmer', 29),
#  ('mexican', 29),
#  ('destroy', 29),
#  ('mix', 29),
#  ('well', 29),
#  ('ruin', 29),
#  ('orphan', 29),
#  ('coach', 29),
#  ('produc', 29),
#  ('system', 29),
#  ('cancer', 29),
#  ('complex', 29),
#  ('defend', 29),
#  ('fan', 29),
#  ('wish', 29),
#  ('outsid', 29),
#  ('drive', 29),
#  ('part', 29),
#  ('wonder', 29),
#  ('imagin', 29),
#  ('author', 29),
#  ('hide', 29),
#  ('contest', 29),
#  ('task', 29),
#  ('technolog', 29),
#  ('second', 29),
#  ('recent', 29),
#  ('organ', 29),
#  ('attend', 29),
#  ('noth', 29),
#  ('underworld', 29),
#  ('entangl', 29),
#  ('emerg', 29),
#  ('taken', 29),
#  ('detail', 29),
#  ('faith', 29),
#  ('late', 29),
#  ('know', 28),
#  ('disast', 28),
#  ('extrem', 28),
#  ('action', 28),
#  ('legend', 28),
#  ('aveng', 28),
#  ('guy', 28),
#  ('earli', 28),
#  ('arm', 28),
#  ('prepar', 28),
#  ('scene', 28),
#  ('seven', 28),
#  ('also', 28),
#  ('trial', 28),
#  ('dare', 28),
#  ('conflict', 28),
#  ('charm', 28),
#  ('never', 28),
#  ('hollywood', 28),
#  ('cook', 28),
#  ('peac', 28),
#  ('professor', 27),
#  ('thriller', 27),
#  ('gangster', 27),
#  ('launch', 27),
#  ('program', 27),
#  ('trio', 27),
#  ('public', 27),
#  ('link', 27),
#  ('upon', 27),
#  ('execut', 27),
#  ('think', 27),
#  ('claim', 27),
#  ('freedom', 27),
#  ('crash', 27),
#  ('santa', 27),
#  ('pay', 27),
#  ('pass', 27),
#  ('line', 27),
#  ('pressur', 27),
#  ('ever', 27),
#  ('caus', 27),
#  ('beyond', 27),
#  ('scienc', 27),
#  ('tension', 27),
#  ('threat', 27),
#  ('toward', 27),
#  ('season', 27),
#  ('complet', 27),
#  ('sever', 27),
#  ('cours', 27),
#  ('adapt', 27),
#  ('fellow', 26),
#  ('suddenli', 26),
#  ('accident', 26),
#  ('pain', 26),
#  ('grappl', 26),
#  ('shot', 26),
#  ('bachelor', 26),
#  ('shop', 26),
#  ('discuss', 26),
#  ('made', 26),
#  ('desert', 26),
#  ('physic', 26),
#  ('joy', 26),
#  ('expect', 26),
#  ('tough', 26),
#  ('farm', 26),
#  ('brave', 26),
#  ('robot', 26),
#  ('write', 26),
#  ('fresh', 26),
#  ('research', 26),
#  ('chao', 26),
#  ('pack', 26),
#  ('profil', 26),
#  ('web', 26),
#  ('franc', 26),
#  ('middl', 26),
#  ('misfit', 26),
#  ('client', 26),
#  ('de', 26),
#  ('found', 25),
#  ('hospit', 25),
#  ('patient', 25),
#  ('lone', 25),
#  ('divers', 25),
#  ('pregnant', 25),
#  ('agre', 25),
#  ('intellig', 25),
#  ('royal', 25),
#  ('letter', 25),
#  ('among', 25),
#  ('near', 25),
#  ('catch', 25),
#  ('endur', 25),
#  ('lie', 25),
#  ('hot', 25),
#  ('pull', 25),
#  ('addict', 25),
#  ('john', 25),
#  ('actress', 25),
#  ('other', 25),
#  ('privat', 25),
#  ('spi', 25),
#  ('assist', 25),
#  ('con', 25),
#  ('twin', 25),
#  ('far', 24),
#  ('close', 24),
#  ('heal', 24),
#  ('attract', 24),
#  ('suffer', 24),
#  ('princ', 24),
#  ('mountain', 24),
#  ('led', 24),
#  ('million', 24),
#  ('abduct', 24),
#  ('forest', 24),
#  ('sing', 24),
#  ('bulli', 24),
#  ('villain', 24),
#  ('corpor', 24),
#  ('entrepreneur', 24),
#  ('adopt', 24),
#  ('older', 24),
#  ('unfold', 24),
#  ('birth', 24),
#  ('novel', 24),
#  ('odd', 24),
#  ('rivalri', 24),
#  ('eight', 24),
#  ('alway', 24),
#  ('anyth', 24),
#  ('match', 24),
#  ('laugh', 24),
#  ('water', 24),
#  ('abil', 24),
#  ('businessman', 24),
#  ('devast', 23),
#  ('better', 23),
#  ('quirki', 23),
#  ('possibl', 23),
#  ('appear', 23),
#  ('african', 23),
#  ('ask', 23),
#  ('cope', 23),
#  ('north', 23),
#  ('sell', 23),
#  ('choos', 23),
#  ('awkward', 23),
#  ('flee', 23),
#  ('root', 23),
#  ('cheat', 23),
#  ('younger', 23),
#  ('educ', 23),
#  ('hold', 23),
#  ('immigr', 23),
#  ('role', 23),
#  ('continu', 23),
#  ('strive', 23),
#  ('blind', 23),
#  ('biopic', 23),
#  ('fierc', 23),
#  ('believ', 23),
#  ('devot', 23),
#  ('dealer', 23),
#  ('great', 23),
#  ('rural', 23),
#  ('independ', 22),
#  ('influenc', 22),
#  ('schooler', 22),
#  ('ex', 22),
#  ('undercov', 22),
#  ('receiv', 22),
#  ('squad', 22),
#  ('chase', 22),
#  ('accept', 22),
#  ('infiltr', 22),
#  ('shi', 22),
#  ('lifestyl', 22),
#  ('debt', 22),
#  ('hors', 22),
#  ('view', 22),
#  ('resort', 22),
#  ('chines', 22),
#  ('draw', 22),
#  ('isol', 22),
#  ('mentor', 22),
#  ('nurs', 22),
#  ('ordinari', 22),
#  ('daili', 22),
#  ('statu', 22),
#  ('trade', 22),
#  ('white', 22),
#  ('rare', 22),
#  ('drawn', 22),
#  ('nightmar', 22),
#  ('cash', 22),
#  ('weekend', 22),
#  ('princess', 22),
#  ('state', 22),
#  ('consequ', 22),
#  ('superstar', 22),
#  ('michael', 22),
#  ('product', 21),
#  ('interest', 21),
#  ('inherit', 21),
#  ('traffick', 21),
#  ('africa', 21),
#  ('unexpectedli', 21),
#  ('charg', 21),
#  ('korea', 21),
#  ('unawar', 21),
#  ('birthday', 21),
#  ('sens', 21),
#  ('academi', 21),
#  ('fiancé', 21),
#  ('idea', 21),
#  ('teach', 21),
#  ('footbal', 21),
#  ('secur', 21),
#  ('kong', 21),
#  ('youth', 21),
#  ('peril', 21),
#  ('bill', 21),
#  ('witch', 21),
#  ('incid', 21),
#  ('militari', 21),
#  ('hip-hop', 21),
#  ('sight', 21),
#  ('vow', 21),
#  ('readi', 21),
#  ('stumbl', 21),
#  ('cartel', 21),
#  ('account', 21),
#  ('traumat', 21),
#  ('west', 21),
#  ('antholog', 21),
#  ('yet', 21),
#  ('shape', 21),
#  ('sound', 21),
#  ('treasur', 21),
#  ('voic', 21),
#  ('martial', 21),
#  ('bear', 21),
#  ('fire', 21),
#  ('england', 21),
#  ('throw', 21),
#  ('kind', 21),
#  ('collid', 21),
#  ('stolen', 21),
#  ('recount', 21),
#  ('juggl', 21),
#  ('warrior', 21),
#  ('scandal', 21),
#  ('sudden', 21),
#  ('condit', 20),
#  ('moment', 20),
#  ('middle-ag', 20),
#  ('discoveri', 20),
#  ('effort', 20),
#  ('quickli', 20),
#  ('torn', 20),
#  ('common', 20),
#  ('alon', 20),
#  ('surround', 20),
#  ('ring', 20),
#  ('sequel', 20),
#  ('support', 20),
#  ('innoc', 20),
#  ('greatest', 20),
#  ('religi', 20),
#  ('offici', 20),
#  ('intens', 20),
#  ('excit', 20),
#  ('ador', 20),
#  ('halloween', 20),
#  ('everyon', 20),
#  ('ride', 20),
#  ('seemingli', 20),
#  ('hong', 20),
#  ('news', 20),
#  ('fill', 20),
#  ('newli', 20),
#  ('servic', 20),
#  ('court', 20),
#  ('korean', 20),
#  ('perfect', 20),
#  ('whether', 20),
#  ('result', 20),
#  ('respons', 20),
#  ('grandfath', 20),
#  ('model', 20),
#  ('balanc', 20),
#  ('alli', 20),
#  ('fulfil', 20),
#  ('potenti', 20),
#  ('god', 20),
#  ('defi', 20),
#  ('legaci', 20),
#  ('fortun', 20),
#  ('agenc', 20),
#  ('david', 20),
#  ('pet', 20),
#  ('upend', 20),
#  ('dj', 20),
#  ('concert', 20),
#  ('triangl', 20),
#  ('unleash', 20),
#  ('confess', 19),
#  ('loom', 19),
#  ('britain', 19),
#  ('heartbreak', 19),
#  ('griev', 19),
#  ('obstacl', 19),
#  ('choic', 19),
#  ('sweet', 19),
#  ('watch', 19),
#  ('without', 19),
#  ('termin', 19),
#  ('settl', 19),
#  ('abandon', 19),
#  ('suspici', 19),
#  ('invit', 19),
#  ('movement', 19),
#  ('1960', 19),
#  ('affect', 19),
#  ('increasingli', 19),
#  ('financi', 19),
#  ('pose', 19),
#  ('clue', 19),
#  ('seriou', 19),
#  ('guard', 19),
#  ('unusu', 19),
#  ('carri', 19),
#  ('turmoil', 19),
#  ('attent', 19),
#  ('russian', 19),
#  ('ago', 19),
#  ('jail', 19),
#  ('leagu', 19),
#  ...]

# %%
sorted(since_2000.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('young', 66),
#  ('find', 63),
#  ('life', 58),
#  ('love', 55),
#  ('friend', 55),
#  ('famili', 51),
#  ('woman', 46),
#  ('two', 46),
#  ('man', 46),
#  ('world', 43),
#  ('becom', 43),
#  ('must', 42),
#  ('new', 41),
#  ('one', 39),
#  ('make', 38),
#  ('live', 38),
#  ('school', 37),
#  ('take', 37),
#  ('tri', 36),
#  ('help', 36),
#  ('girl', 35),
#  ('seri', 33),
#  ('get', 32),
#  ('power', 32),
#  ('student', 30),
#  ('team', 29),
#  ('stori', 28),
#  ('son', 27),
#  ('father', 26),
#  ('three', 25),
#  ('forc', 25),
#  ('brother', 25),
#  ('day', 24),
#  ('murder', 24),
#  ('set', 23),
#  ('turn', 23),
#  ('home', 23),
#  ('group', 22),
#  ('true', 22),
#  ('dream', 22),
#  ('begin', 22),
#  ('secret', 22),
#  ('daughter', 22),
#  ('film', 21),
#  ('marri', 21),
#  ('work', 21),
#  ('high', 21),
#  ('four', 21),
#  ('come', 21),
#  ('discov', 21),
#  ('move', 20),
#  ('``', 20),
#  ('return', 20),
#  ('fall', 19),
#  ('save', 18),
#  ('documentari', 18),
#  ("n't", 18),
#  ('learn', 18),
#  ('follow', 18),
#  ('meet', 17),
#  ('death', 17),
#  ('struggl', 17),
#  ('boy', 17),
#  ('agent', 17),
#  ('star', 17),
#  ('join', 16),
#  ('villag', 16),
#  ('chang', 16),
#  ('year', 16),
#  ('may', 16),
#  ('evil', 16),
#  ('coupl', 16),
#  ('human', 16),
#  ('citi', 16),
#  ('comedi', 16),
#  ('adventur', 16),
#  ('anim', 16),
#  ('wife', 15),
#  ('soon', 15),
#  ('colleg', 15),
#  ('five', 15),
#  ('member', 15),
#  ('rais', 15),
#  ('battl', 15),
#  ('crime', 15),
#  ('relationship', 15),
#  ('plan', 15),
#  ('goe', 15),
#  ('cop', 14),
#  ('india', 14),
#  ('drama', 14),
#  ('mysteri', 14),
#  ('back', 14),
#  ('face', 14),
#  ('indian', 14),
#  ('marriag', 14),
#  ('play', 13),
#  ('bring', 13),
#  ('job', 13),
#  ('romanc', 13),
#  ('lose', 13),
#  ('leav', 13),
#  ('american', 13),
#  ('sister', 13),
#  ('pair', 13),
#  ('train', 13),
#  ('differ', 13),
#  ('time', 13),
#  ('person', 13),
#  ('husband', 13),
#  ('alien', 13),
#  ('govern', 12),
#  ('togeth', 12),
#  ('seek', 12),
#  ('threaten', 12),
#  ('go', 12),
#  ('old', 12),
#  ('search', 12),
#  ('charm', 12),
#  ('town', 12),
#  ('way', 12),
#  ('gang', 12),
#  ('wed', 12),
#  ('reveal', 12),
#  ('mother', 12),
#  ('head', 12),
#  ('determin', 11),
#  ('rescu', 11),
#  ('men', 11),
#  ('win', 11),
#  ('put', 11),
#  ('land', 11),
#  ('women', 11),
#  ('behind', 11),
#  ('teenag', 11),
#  ('look', 11),
#  ('plot', 11),
#  ('wealthi', 11),
#  ('travel', 11),
#  ('drug', 11),
#  ('money', 11),
#  ('hit', 11),
#  ('base', 11),
#  ('lead', 11),
#  ('war', 11),
#  ('career', 11),
#  ('art', 10),
#  ('teacher', 10),
#  ('teen', 10),
#  ('kid', 10),
#  ('professor', 10),
#  ('realiz', 10),
#  ('accid', 10),
#  ('polit', 10),
#  ('hope', 10),
#  ('long', 10),
#  ('heart', 10),
#  ('kidnap', 10),
#  ('use', 10),
#  ('whose', 10),
#  ('event', 10),
#  ('magic', 10),
#  ('demon', 10),
#  ('littl', 10),
#  ('troubl', 10),
#  ('york', 10),
#  ('offic', 10),
#  ('rich', 10),
#  ('mission', 10),
#  ('mumbai', 10),
#  ('pal', 10),
#  ('spirit', 10),
#  ('kill', 10),
#  ('first', 10),
#  ('peopl', 9),
#  ('master', 9),
#  ('earth', 9),
#  ('best', 9),
#  ('navig', 9),
#  ('polic', 9),
#  ('terrorist', 9),
#  ('start', 9),
#  ('british', 9),
#  ('crew', 9),
#  ('past', 9),
#  ('ident', 9),
#  ('local', 9),
#  ('investig', 9),
#  ('run', 9),
#  ('night', 9),
#  ('inspir', 9),
#  ('scheme', 9),
#  ('actor', 9),
#  ('stranger', 9),
#  ('still', 9),
#  ('gangster', 9),
#  ('call', 9),
#  ('charact', 9),
#  ('end', 9),
#  ('reunit', 9),
#  ('unlik', 9),
#  ('protect', 9),
#  ('univers', 9),
#  ('car', 9),
#  ('hous', 9),
#  ('trip', 9),
#  ('around', 9),
#  ('thing', 9),
#  ('arriv', 9),
#  ('keep', 9),
#  ('wit', 8),
#  ('captur', 8),
#  ('last', 8),
#  ('report', 8),
#  ('six', 8),
#  ('test', 8),
#  ('killer', 8),
#  ('social', 8),
#  ('music', 8),
#  ('featur', 8),
#  ('role', 8),
#  ('see', 8),
#  ('hear', 8),
#  ('busi', 8),
#  ('businessman', 8),
#  ('fortun', 8),
#  ('race', 8),
#  ('attack', 8),
#  ('fight', 8),
#  ('widow', 8),
#  ('countri', 8),
#  ('challeng', 8),
#  ('big', 8),
#  ('entertain', 8),
#  ('action', 8),
#  ('destroy', 8),
#  ('real', 8),
#  ('tale', 8),
#  ('show', 8),
#  ('former', 8),
#  ('scene', 8),
#  ('unit', 8),
#  ('beauti', 8),
#  ('tv', 8),
#  ('ring', 8),
#  ('escap', 8),
#  ('involv', 8),
#  ('break', 8),
#  ('final', 8),
#  ('special', 8),
#  ('comic', 8),
#  ('decid', 8),
#  ('prove', 8),
#  ('feel', 8),
#  ('ninja', 8),
#  ('ranger', 8),
#  ('stop', 7),
#  ('leader', 7),
#  ('task', 7),
#  ('journalist', 7),
#  ('everi', 7),
#  ('danc', 7),
#  ('happi', 7),
#  ('unexpect', 7),
#  ('die', 7),
#  ('deal', 7),
#  ('rule', 7),
#  ('steal', 7),
#  ('bollywood', 7),
#  ('epic', 7),
#  ('encount', 7),
#  ('prison', 7),
#  ('attempt', 7),
#  ('realiti', 7),
#  ('game', 7),
#  ('appear', 7),
#  ('hollywood', 7),
#  ('visit', 7),
#  ('rise', 7),
#  ('dealer', 7),
#  ('girlfriend', 7),
#  ('con', 7),
#  ('fbi', 7),
#  ('parti', 7),
#  ('armi', 7),
#  ('arrang', 7),
#  ('includ', 7),
#  ('wild', 7),
#  ('fate', 7),
#  ('date', 7),
#  ('reveng', 7),
#  ('develop', 7),
#  ('orphan', 7),
#  ('boyfriend', 7),
#  ('experi', 7),
#  ('crimin', 7),
#  ('success', 7),
#  ('everyth', 7),
#  ('partner', 7),
#  ('friendship', 7),
#  ('notori', 7),
#  ('danger', 6),
#  ('assassin', 6),
#  ('journey', 6),
#  ('wish', 6),
#  ('singl', 6),
#  ('found', 6),
#  ('care', 6),
#  ('cast', 6),
#  ('apart', 6),
#  ('classmat', 6),
#  ('commun', 6),
#  ('anoth', 6),
#  ('case', 6),
#  ('good', 6),
#  ('surpris', 6),
#  ('twin', 6),
#  ('haunt', 6),
#  ('fake', 6),
#  ('worker', 6),
#  ('princess', 6),
#  ('give', 6),
#  ('perform', 6),
#  ('increasingli', 6),
#  ('movi', 6),
#  ('u.s.', 6),
#  ('biggest', 6),
#  ('america', 6),
#  ('examin', 6),
#  ('eccentr', 6),
#  ('modern', 6),
#  ('footbal', 6),
#  ('club', 6),
#  ('stand', 6),
#  ('gift', 6),
#  ('parent', 6),
#  ('boss', 6),
#  ('water', 6),
#  ('hire', 6),
#  ('christma', 6),
#  ('bitter', 6),
#  ('ancient', 6),
#  ('martial', 6),
#  ('want', 6),
#  ('account', 6),
#  ('bond', 6),
#  ('planet', 6),
#  ('yet', 6),
#  ('seemingli', 6),
#  ('employe', 6),
#  ('road', 6),
#  ('forev', 6),
#  ('charismat', 6),
#  ('well', 6),
#  ('driver', 6),
#  ('chao', 6),
#  ('park', 6),
#  ('explor', 6),
#  ('rival', 6),
#  ('naruto', 6),
#  ('robot', 5),
#  ('fear', 5),
#  ('expert', 5),
#  ('insid', 5),
#  ('hunter', 5),
#  ('age', 5),
#  ('lucki', 5),
#  ('pari', 5),
#  ('fellow', 5),
#  ('engin', 5),
#  ('lost', 5),
#  ('cours', 5),
#  ('millionair', 5),
#  ('think', 5),
#  ('center', 5),
#  ('lover', 5),
#  ('bad', 5),
#  ('thriller', 5),
#  ('order', 5),
#  ('london', 5),
#  ('mishap', 5),
#  ('amid', 5),
#  ('south', 5),
#  ('treasur', 5),
#  ('ruin', 5),
#  ('stumbl', 5),
#  ('fame', 5),
#  ('singer', 5),
#  ('stolen', 5),
#  ('diamond', 5),
#  ('caught', 5),
#  ('corrupt', 5),
#  ('great', 5),
#  ('sibl', 5),
#  ('act', 5),
#  ('across', 5),
#  ('black', 5),
#  ('away', 5),
#  ('place', 5),
#  ('deliv', 5),
#  ('offer', 5),
#  ('pursu', 5),
#  ('better', 5),
#  ('mean', 5),
#  ('pay', 5),
#  ('upsid', 5),
#  ('share', 5),
#  ('track', 5),
#  ('musician', 5),
#  ('band', 5),
#  ('frame', 5),
#  ('might', 5),
#  ('without', 5),
#  ('shot', 5),
#  ('soul', 5),
#  ('truth', 5),
#  ('embark', 5),
#  ('solv', 5),
#  ('tradit', 5),
#  ('recruit', 5),
#  ('player', 5),
#  ('celebr', 5),
#  ('doctor', 5),
#  ('older', 5),
#  ('jealousi', 5),
#  ('avoid', 5),
#  ('10-year-old', 5),
#  ('seem', 5),
#  ('terror', 5),
#  ('compani', 5),
#  ('form', 5),
#  ('classic', 5),
#  ('angel', 5),
#  ('militari', 5),
#  ('taken', 5),
#  ('grow', 5),
#  ('coach', 5),
#  ('chronicl', 5),
#  ('undercov', 5),
#  ('agre', 5),
#  ('adult', 5),
#  ('perfect', 5),
#  ('ii', 5),
#  ('hospit', 5),
#  ('season', 5),
#  ('north', 5),
#  ('host', 5),
#  ('holiday', 5),
#  ('tell', 5),
#  ('met', 5),
#  ('soldier', 5),
#  ('competit', 5),
#  ('dark', 5),
#  ('prequel', 5),
#  ('nazi', 5),
#  ('bill', 5),
#  ('commit', 5),
#  ('bank', 5),
#  ('compet', 5),
#  ('children', 5),
#  ('spend', 5),
#  ('divorc', 5),
#  ('decad', 5),
#  ('left', 5),
#  ('misadventur', 5),
#  ('thwart', 5),
#  ('awaken', 5),
#  ('independ', 5),
#  ('rock', 5),
#  ('televis', 5),
#  ('employ', 5),
#  ('ambiti', 5),
#  ('suddenli', 5),
#  ('know', 5),
#  ('aspir', 5),
#  ('organ', 5),
#  ('presid', 5),
#  ('lie', 5),
#  ('stand-up', 5),
#  ('11-year-old', 5),
#  ('popular', 5),
#  ('dad', 5),
#  ('writer', 5),
#  ('king', 5),
#  ('entir', 5),
#  ('ocean', 5),
#  ('question', 5),
#  ('sent', 5),
#  ('machin', 4),
#  ('million', 4),
#  ('vega', 4),
#  ('someth', 4),
#  ('aim', 4),
#  ('top', 4),
#  ('near', 4),
#  ('crisi', 4),
#  ('bumbl', 4),
#  ('thief', 4),
#  ('even', 4),
#  ('resid', 4),
#  ('interview', 4),
#  ('emerg', 4),
#  ('unravel', 4),
#  ('jewish', 4),
#  ('gay', 4),
#  ('tragedi', 4),
#  ('receiv', 4),
#  ('retriev', 4),
#  ('carri', 4),
#  ('skill', 4),
#  ('prep', 4),
#  ('footag', 4),
#  ('emot', 4),
#  ('heal', 4),
#  ('other', 4),
#  ('pick', 4),
#  ('enlist', 4),
#  ('manag', 4),
#  ('issu', 4),
#  ('unawar', 4),
#  ('tragic', 4),
#  ('youth', 4),
#  ('enemi', 4),
#  ('veng', 4),
#  ('warrior', 4),
#  ('childhood', 4),
#  ('overcom', 4),
#  ('spi', 4),
#  ('continu', 4),
#  ('dr.', 4),
#  ('villain', 4),
#  ('lawyer', 4),
#  ('rural', 4),
#  ('defeat', 4),
#  ('nation', 4),
#  ('sequel', 4),
#  ('voic', 4),
#  ('ransom', 4),
#  ('buddi', 4),
#  ('debt', 4),
#  ('action-pack', 4),
#  ('kingdom', 4),
#  ('told', 4),
#  ('point', 4),
#  ('tour', 4),
#  ('major', 4),
#  ('trade', 4),
#  ('talent', 4),
#  ('cover', 4),
#  ('georg', 4),
#  ('poverti', 4),
#  ('stay', 4),
#  ('await', 4),
#  ('spoil', 4),
#  ('conflict', 4),
#  ('trio', 4),
#  ('shock', 4),
#  ('global', 4),
#  ('child', 4),
#  ('newli', 4),
#  ('push', 4),
#  ('problem', 4),
#  ('dare', 4),
#  ('door', 4),
#  ('inform', 4),
#  ('believ', 4),
#  ('hatch', 4),
#  ('control', 4),
#  ('controversi', 4),
#  ('farmer', 4),
#  ('mask', 4),
#  ('arm', 4),
#  ('infiltr', 4),
#  ('transport', 4),
#  ('strang', 4),
#  ('lo', 4),
#  ('walk', 4),
#  ('lee', 4),
#  ('strand', 4),
#  ('jungl', 4),
#  ('horror', 4),
#  ('adolesc', 4),
#  ('sex', 4),
#  ('surgeon', 4),
#  ('accus', 4),
#  ('innoc', 4),
#  ('send', 4),
#  ('scienc', 4),
#  ('chase', 4),
#  ('effort', 4),
#  ('accept', 4),
#  ('mom', 4),
#  ('everyon', 4),
#  ('storm', 4),
#  ('side', 4),
#  ('blockbust', 4),
#  ('respons', 4),
#  ('imprison', 4),
#  ('trust', 4),
#  ('enigmat', 4),
#  ('peac', 4),
#  ('summon', 4),
#  ('prepar', 4),
#  ('guy', 4),
#  ('giant', 4),
#  ('remak', 4),
#  ('among', 4),
#  ('politician', 4),
#  ('handsom', 4),
#  ('wrong', 4),
#  ('comedian', 4),
#  ('next', 4),
#  ('mr.', 4),
#  ('right', 4),
#  ('veteran', 4),
#  ('belov', 4),
#  ('medic', 4),
#  ('fantasi', 4),
#  ('director', 4),
#  ('histori', 4),
#  ('moment', 4),
#  ('catch', 4),
#  ('ca', 4),
#  ('impress', 4),
#  ('monk', 4),
#  ('honeymoon', 4),
#  ('abandon', 4),
#  ('street', 4),
#  ('femal', 4),
#  ('match', 4),
#  ('japanes', 4),
#  ('could', 4),
#  ('romant', 4),
#  ('cultur', 4),
#  ('alter', 4),
#  ('hilari', 4),
#  ('cut', 4),
#  ('caus', 4),
#  ('board', 4),
#  ('elit', 4),
#  ('academi', 4),
#  ('respect', 4),
#  ('monti', 4),
#  ('cross', 4),
#  ('arrog', 4),
#  ('ill', 4),
#  ('instal', 4),
#  ('letter', 4),
#  ('shape', 4),
#  ('staff', 4),
#  ('station', 4),
#  ('origin', 4),
#  ('link', 4),
#  ('awri', 4),
#  ('surviv', 4),
#  ('senior', 4),
#  ('urban', 4),
#  ('hide', 3),
#  ('intent', 3),
#  ('swindl', 3),
#  ('la', 3),
#  ('architect', 3),
#  ('castl', 3),
#  ('escort', 3),
#  ('trek', 3),
#  ('mike', 3),
#  ('wake', 3),
#  ('elud', 3),
#  ('antic', 3),
#  ('result', 3),
#  ('properti', 3),
#  ('enter', 3),
#  ('attend', 3),
#  ('beat', 3),
#  ('system', 3),
#  ('pretti', 3),
#  ('memori', 3),
#  ('marin', 3),
#  ('sam', 3),
#  ('cell', 3),
#  ('phone', 3),
#  ('longtim', 3),
#  ('recent', 3),
#  ('crush', 3),
#  ('anonym', 3),
#  ('bomb', 3),
#  ('demand', 3),
#  ('due', 3),
#  ('imaginari', 3),
#  ('lethal', 3),
#  ('loner', 3),
#  ('cocain', 3),
#  ('remot', 3),
#  ('execut', 3),
#  ('drive', 3),
#  ('els', 3),
#  ('guru', 3),
#  ('woo', 3),
#  ('homicid', 3),
#  ('detect', 3),
#  ('fascin', 3),
#  ('africa', 3),
#  ('pursuit', 3),
#  ('urg', 3),
#  ('hunt', 3),
#  ('buri', 3),
#  ('beneath', 3),
#  ('subway', 3),
#  ('onto', 3),
#  ('uncov', 3),
#  ('mob', 3),
#  ('trail', 3),
#  ('templ', 3),
#  ('eye', 3),
#  ('activist', 3),
#  ('kingpin', 3),
#  ('transform', 3),
#  ('legendari', 3),
#  ('promis', 3),
#  ('1970', 3),
#  ('fire', 3),
#  ('bloodi', 3),
#  ('connect', 3),
#  ('adopt', 3),
#  ('like', 3),
#  ('dog', 3),
#  ('plane', 3),
#  ('tough', 3),
#  ('interest', 3),
#  ('shift', 3),
#  ('cup', 3),
#  ('serv', 3),
#  ('novelist', 3),
#  ('stuck', 3),
#  ('kind', 3),
#  ('ben', 3),
#  ('current', 3),
#  ('lock', 3),
#  ('mani', 3),
#  ('secretli', 3),
#  ('siddharth', 3),
#  ('greedi', 3),
#  ('produc', 3),
#  ('credit', 3),
#  ('nick', 3),
#  ('small', 3),
#  ('process', 3),
#  ('book', 3),
#  ('anyon', 3),
#  ('cloud', 3),
#  ('artist', 3),
#  ('root', 3),
#  ('bo', 3),
#  ('dragon', 3),
#  ('ship', 3),
#  ('recov', 3),
#  ('nativ', 3),
#  ('cliqu', 3),
#  ('divid', 3),
#  ('fatal', 3),
#  ('jail', 3),
#  ('late', 3),
#  ('pose', 3),
#  ('profession', 3),
#  ('naïv', 3),
#  ('abus', 3),
#  ('007', 3),
#  ('pit', 3),
#  ('financi', 3),
#  ('tabl', 3),
#  ('frank', 3),
#  ('bar', 3),
#  ('readi', 3),
#  ('bell', 3),
#  ('sophist', 3),
#  ('invest', 3),
#  ('factori', 3),
#  ('kick', 3),
#  ('sexi', 3),
#  ('faith', 3),
#  ('neighbor', 3),
#  ('soccer', 3),
#  ('sever', 3),
#  ('inventor', 3),
#  ('citizen', 3),
#  ('disast', 3),
#  ('manhattan', 3),
#  ('monster', 3),
#  ('sport', 3),
#  ('poor', 3),
#  ('lord', 3),
#  ('19th-centuri', 3),
#  ('erupt', 3),
#  ('china', 3),
#  ('union', 3),
#  ('kim', 3),
#  ('pole', 3),
#  ('onlin', 3),
#  ('close-knit', 3),
#  ('undead', 3),
#  ('extraordinari', 3),
#  ('collector', 3),
#  ('path', 3),
#  ('natur', 3),
#  ('simpl', 3),
#  ('meteorit', 3),
#  ('resist', 3),
#  ('complex', 3),
#  ('ruthless', 3),
#  ('wipe', 3),
#  ('favorit', 3),
#  ('ghost', 3),
#  ('scam', 3),
#  ('short', 3),
#  ('unorthodox', 3),
#  ('name', 3),
#  ('mobster', 3),
#  ('never', 3),
#  ('claim', 3),
#  ('regim', 3),
#  ('punish', 3),
#  ('evan', 3),
#  ('build', 3),
#  ('juggl', 3),
#  ('andi', 3),
#  ('sentenc', 3),
#  ('small-town', 3),
#  ('situat', 3),
#  ('ultim', 3),
#  ('whole', 3),
#  ('cheat', 3),
#  ('premonit', 3),
#  ('prevent', 3),
#  ('assist', 3),
#  ('attorney', 3),
#  ('santa', 3),
#  ('rap', 3),
#  ('merri', 3),
#  ('immigr', 3),
#  ('also', 3),
#  ('garfield', 3),
#  ('trap', 3),
#  ('anyth', 3),
#  ('far', 3),
#  ('indonesian', 3),
#  ('sharp', 3),
#  ('environ', 3),
#  ('relat', 3),
#  ('jealou', 3),
#  ('engag', 3),
#  ('joseph', 3),
#  ('threat', 3),
#  ('gather', 3),
#  ('william', 3),
#  ('closer', 3),
#  ('seven', 3),
#  ('video', 3),
#  ('franchis', 3),
#  ('quit', 3),
#  ('cricket', 3),
#  ('charg', 3),
#  ('ambit', 3),
#  ('fast-pac', 3),
#  ('thrown', 3),
#  ('newlyw', 3),
#  ('pet', 3),
#  ('rob', 3),
#  ('russian', 3),
#  ('owner', 3),
#  ('occupi', 3),
#  ('retir', 3),
#  ('clash', 3),
#  ('fund', 3),
#  ('tie', 3),
#  ('inuyasha', 3),
#  ('third', 3),
#  ('seal', 3),
#  ('gener', 3),
#  ('speech', 3),
#  ('athlet', 3),
#  ('nefari', 3),
#  ('product', 3),
#  ('half', 3),
#  ('irrever', 3),
#  ('inherit', 3),
#  ('nuclear', 3),
#  ('up-and-com', 3),
#  ('jim', 3),
#  ('topic', 3),
#  ('hot', 3),
#  ('jimmi', 3),
#  ('opportun', 3),
#  ('color', 3),
#  ('cook', 3),
#  ('affair', 3),
#  ('uptight', 3),
#  ('wealth', 3),
#  ('law', 3),
#  ('uncl', 3),
#  ('2006', 3),
#  ('bride', 3),
#  ('string', 3),
#  ('drop', 3),
#  ('gain', 3),
#  ('donkey', 3),
#  ('pretend', 3),
#  ('luck', 3),
#  ('sweet', 3),
#  ('chanc', 3),
#  ('devil', 3),
#  ('singapor', 3),
#  ('project', 3),
#  ('possess', 3),
#  ('civilian', 3),
#  ('disgruntl', 3),
#  ('insight', 3),
#  ('sketch', 3),
#  ('troup', 3),
#  ('humor', 3),
#  ('python', 3),
#  ('empir', 3),
#  ('condit', 3),
#  ('settl', 3),
#  ('prodigi', 3),
#  ('entangl', 3),
#  ('triangl', 3),
#  ('suicid', 3),
#  ('miss', 3),
#  ('princ', 3),
#  ('trace', 3),
#  ('surround', 3),
#  ('john', 3),
#  ('ignit', 3),
#  ('danni', 3),
#  ('line', 3),
#  ('piec', 3),
#  ('clutch', 3),
#  ('petti', 3),
#  ('step', 3),
#  ('tangl', 3),
#  ('hold', 3),
#  ('desper', 3),
#  ('eve', 3),
#  ('morph', 3),
#  ('mystic', 3),
#  ('space', 3),
#  ('spark', 3),
#  ('class', 3),
#  ('target', 3),
#  ('theme', 3),
#  ('matrix', 3),
#  ('crop', 3),
#  ('carmen', 3),
#  ('juni', 3),
#  ('scientist', 3),
#  ('let', 3),
#  ('war-torn', 3),
#  ('rivalri', 3),
#  ('pro', 3),
#  ('priceless', 3),
#  ('bubbl', 3),
#  ('extermin', 2),
#  ('brilliant', 2),
#  ('casino', 2),
#  ('hotel', 2),
#  ('upris', 2),
#  ('underground', 2),
#  ('rebellion', 2),
#  ('dispatch', 2),
#  ('acrobat', 2),
#  ('elimin', 2),
#  ('fierc', 2),
#  ('mammoth', 2),
#  ('warlord', 2),
#  ('court', 2),
#  ('aliv', 2),
#  ('midlif', 2),
#  ('exactli', 2),
#  ('policeman', 2),
#  ('alcohol', 2),
#  ('rehab', 2),
#  ('solicit', 2),
#  ('premier', 2),
#  ('trauma', 2),
#  ('cancer', 2),
#  ('ian', 2),
#  ('physic', 2),
#  ('optimist', 2),
#  ('opposit', 2),
#  ('bloom', 2),
#  ('tear', 2),
#  ('tip', 2),
#  ('full', 2),
#  ('hero', 2),
#  ('invent', 2),
#  ('contract', 2),
#  ('stage', 2),
#  ('victim', 2),
#  ('song', 2),
#  ('fallout', 2),
#  ...]

# %%
sorted(since_1980.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('young', 34),
#  ('love', 32),
#  ('famili', 31),
#  ('life', 29),
#  ('man', 27),
#  ('take', 24),
#  ('new', 22),
#  ('fall', 22),
#  ('woman', 20),
#  ('power', 20),
#  ('murder', 19),
#  ('becom', 19),
#  ('find', 19),
#  ('must', 18),
#  ('help', 17),
#  ('turn', 17),
#  ('friend', 17),
#  ('``', 16),
#  ('tri', 16),
#  ('two', 15),
#  ('brother', 15),
#  ('return', 15),
#  ('live', 15),
#  ('forc', 15),
#  ('father', 15),
#  ('one', 14),
#  ('school', 14),
#  ('work', 14),
#  ('girl', 14),
#  ('get', 13),
#  ('three', 13),
#  ('set', 12),
#  ('boy', 12),
#  ('cop', 12),
#  ('crimin', 11),
#  ('whose', 11),
#  ('come', 11),
#  ('world', 11),
#  ('wealthi', 11),
#  ('son', 11),
#  ('fight', 11),
#  ('marri', 11),
#  ('student', 10),
#  ('teen', 10),
#  ('daughter', 10),
#  ('agent', 10),
#  ('master', 10),
#  ('crime', 10),
#  ('seri', 10),
#  ('war', 10),
#  ('stori', 10),
#  ('face', 9),
#  ('death', 9),
#  ('wife', 9),
#  ('evil', 9),
#  ('stop', 9),
#  ('meet', 9),
#  ('show', 9),
#  ('teenag', 9),
#  ('battl', 9),
#  ('team', 9),
#  ('grow', 8),
#  ('move', 8),
#  ('home', 8),
#  ('comedi', 8),
#  ('kill', 8),
#  ('run', 8),
#  ('reveng', 8),
#  ('join', 8),
#  ('angel', 8),
#  ('back', 8),
#  ('struggl', 8),
#  ('follow', 8),
#  ('make', 8),
#  ('mysteri', 8),
#  ('secret', 8),
#  ('scheme', 8),
#  ('perform', 8),
#  ('film', 8),
#  ('town', 8),
#  ('group', 8),
#  ('best', 8),
#  ('gang', 7),
#  ('hope', 7),
#  ('parent', 7),
#  ('play', 7),
#  ('base', 7),
#  ('prison', 7),
#  ('way', 7),
#  ('heart', 7),
#  ('discov', 7),
#  ('action', 7),
#  ('star', 7),
#  ('beauti', 7),
#  ('rise', 7),
#  ('former', 7),
#  ('learn', 7),
#  ('killer', 7),
#  ('seek', 7),
#  ('drama', 7),
#  ('age', 7),
#  ('art', 7),
#  ('decid', 7),
#  ('escap', 7),
#  ('begin', 7),
#  ('lead', 7),
#  ('mission', 7),
#  ('high', 6),
#  ('justic', 6),
#  ('polic', 6),
#  ('orphan', 6),
#  ('earth', 6),
#  ('sent', 6),
#  ('wild', 6),
#  ('plan', 6),
#  ('men', 6),
#  ('investig', 6),
#  ('girlfriend', 6),
#  ('jail', 6),
#  ('magic', 6),
#  ('creat', 6),
#  ('bond', 6),
#  ('danger', 6),
#  ('leav', 6),
#  ('rival', 6),
#  ('troubl', 6),
#  ('husband', 6),
#  ('law', 6),
#  ('deadli', 6),
#  ('classic', 6),
#  ('sister', 6),
#  ('twin', 6),
#  ('night', 5),
#  ('child', 5),
#  ('bring', 5),
#  ('releas', 5),
#  ('goe', 5),
#  ('may', 5),
#  ('anim', 5),
#  ('chang', 5),
#  ('adventur', 5),
#  ('marriag', 5),
#  ('day', 5),
#  ('travel', 5),
#  ('challeng', 5),
#  ('everyth', 5),
#  ('four', 5),
#  ('icon', 5),
#  ('comedian', 5),
#  ('made', 5),
#  ('talent', 5),
#  ('charact', 5),
#  ('partner', 5),
#  ('soon', 5),
#  ('documentari', 5),
#  ('member', 5),
#  ('deliv', 5),
#  ('plot', 5),
#  ('lose', 5),
#  ('start', 5),
#  ('use', 5),
#  ('mother', 5),
#  ('lawyer', 5),
#  ('defend', 5),
#  ('childhood', 5),
#  ('ident', 5),
#  ('social', 5),
#  ('win', 5),
#  ('question', 5),
#  ('year', 5),
#  ('crew', 5),
#  ('terrorist', 5),
#  ('hit', 5),
#  ('ninja', 5),
#  ('violent', 5),
#  ('tale', 5),
#  ('put', 5),
#  ('conflict', 5),
#  ('fate', 5),
#  ('separ', 5),
#  ('reunit', 5),
#  ('past', 5),
#  ('colleg', 5),
#  ('kidnap', 5),
#  ('game', 5),
#  ('train', 5),
#  ('ranger', 5),
#  ('attack', 4),
#  ('teacher', 4),
#  ('york', 4),
#  ('citi', 4),
#  ('widow', 4),
#  ('despit', 4),
#  ('job', 4),
#  ('rais', 4),
#  ('nation', 4),
#  ('children', 4),
#  ('career', 4),
#  ('polit', 4),
#  ('artist', 4),
#  ('younger', 4),
#  ('mous', 4),
#  ('deep', 4),
#  ('report', 4),
#  ('chamber', 4),
#  ('drawn', 4),
#  ('neighbor', 4),
#  ('prove', 4),
#  ('british', 4),
#  ('superspi', 4),
#  ('time', 4),
#  ('human', 4),
#  ("n't", 4),
#  ('detect', 4),
#  ('book', 4),
#  ('hilari', 4),
#  ('kid', 4),
#  ('dump', 4),
#  ('host', 4),
#  ('businessman', 4),
#  ('peopl', 4),
#  ('comic', 4),
#  ('sam', 4),
#  ('includ', 4),
#  ('civil', 4),
#  ('diagnos', 4),
#  ('enemi', 4),
#  ('everyon', 4),
#  ('american', 4),
#  ('stand-up', 4),
#  ('govern', 4),
#  ('shaolin', 4),
#  ('protect', 4),
#  ('frame', 4),
#  ('navig', 4),
#  ('unawar', 4),
#  ('attorney', 4),
#  ('household', 4),
#  ('name', 4),
#  ('featur', 4),
#  ('big', 4),
#  ('nerv', 4),
#  ('embark', 4),
#  ('vow', 4),
#  ('order', 4),
#  ('boxer', 4),
#  ('competit', 4),
#  ('martial', 4),
#  ('clan', 4),
#  ('affair', 4),
#  ('jone', 4),
#  ('legendari', 4),
#  ('differ', 4),
#  ('tv', 4),
#  ('presid', 4),
#  ('arriv', 4),
#  ('romanc', 4),
#  ('upon', 4),
#  ('stage', 4),
#  ('small', 4),
#  ('track', 4),
#  ('dedic', 3),
#  ('gain', 3),
#  ('sketch', 3),
#  ('philand', 3),
#  ('rich', 3),
#  ('much', 3),
#  ('unleash', 3),
#  ('intrepid', 3),
#  ('hand', 3),
#  ('thief', 3),
#  ('abduct', 3),
#  ('john', 3),
#  ('gangster', 3),
#  ('mobster', 3),
#  ('reckon', 3),
#  ('villag', 3),
#  ('endur', 3),
#  ('fievel', 3),
#  ('russian', 3),
#  ('head', 3),
#  ('cowboy', 3),
#  ('london', 3),
#  ('charm', 3),
#  ('gay', 3),
#  ('nazi', 3),
#  ('foil', 3),
#  ('dr.', 3),
#  ('crook', 3),
#  ('heroin', 3),
#  ('popular', 3),
#  ('rock', 3),
#  ('brutal', 3),
#  ('prime', 3),
#  ('suspect', 3),
#  ('stand', 3),
#  ('mr.', 3),
#  ('lo', 3),
#  ('famou', 3),
#  ('paint', 3),
#  ('realiz', 3),
#  ('surpris', 3),
#  ('spirit', 3),
#  ('offer', 3),
#  ('wish', 3),
#  ('choos', 3),
#  ('favorit', 3),
#  ('refus', 3),
#  ('accept', 3),
#  ('bill', 3),
#  ('hick', 3),
#  ('music', 3),
#  ('special', 3),
#  ('like', 3),
#  ('style', 3),
#  ('eccentr', 3),
#  ('graduat', 3),
#  ('creatur', 3),
#  ('break', 3),
#  ('hong', 3),
#  ('kong', 3),
#  ('top', 3),
#  ('busi', 3),
#  ('wit', 3),
#  ('massiv', 3),
#  ('singer', 3),
#  ('anoth', 3),
#  ('ghost', 3),
#  ('owner', 3),
#  ('even', 3),
#  ('parodi', 3),
#  ('believ', 3),
#  ('cult', 3),
#  ('sexual', 3),
#  ('abus', 3),
#  ('scene', 3),
#  ('truth', 3),
#  ('care', 3),
#  ('around', 3),
#  ('u.s.', 3),
#  ('serv', 3),
#  ('millionair', 3),
#  ('actual', 3),
#  ('door', 3),
#  ('monk', 3),
#  ('poor', 3),
#  ('fbi', 3),
#  ('charg', 3),
#  ('die', 3),
#  ('last', 3),
#  ('case', 3),
#  ('observ', 3),
#  ('belov', 3),
#  ('india', 3),
#  ('form', 3),
#  ('movi', 3),
#  ('impact', 3),
#  ('destroy', 3),
#  ('receiv', 3),
#  ('rescu', 3),
#  ('assign', 3),
#  ('entir', 3),
#  ('act', 3),
#  ('seemingli', 3),
#  ('sinc', 3),
#  ('court', 3),
#  ('true', 3),
#  ('torn', 3),
#  ('apart', 3),
#  ('give', 3),
#  ('pierc', 3),
#  ('first', 3),
#  ('jame', 3),
#  ('weapon', 3),
#  ('save', 3),
#  ('fire', 3),
#  ('search', 3),
#  ('never', 3),
#  ('soldier', 3),
#  ('tell', 3),
#  ('determin', 3),
#  ('notori', 3),
#  ('spoil', 3),
#  ('crash', 3),
#  ('victim', 3),
#  ('aveng', 3),
#  ('scientist', 3),
#  ('explor', 3),
#  ('mark', 3),
#  ('embrac', 3),
#  ('summer', 3),
#  ('interest', 3),
#  ('matriarch', 3),
#  ('disabl', 3),
#  ('fortun', 3),
#  ('within', 3),
#  ('dead', 3),
#  ('indiana', 3),
#  ('hunt', 3),
#  ('hire', 3),
#  ('shankar', 3),
#  ('abandon', 3),
#  ('caught', 3),
#  ('end', 3),
#  ('real', 3),
#  ('prey', 3),
#  ('later', 3),
#  ('thing', 3),
#  ('women', 3),
#  ('buddi', 3),
#  ('also', 3),
#  ('assassin', 3),
#  ('kung', 3),
#  ('fu', 3),
#  ('leader', 3),
#  ('loyalti', 3),
#  ('space', 3),
#  ('right', 3),
#  ('mutant', 3),
#  ('turtl', 3),
#  ('addict', 3),
#  ('beirut', 3),
#  ('studi', 3),
#  ('terror', 3),
#  ('storm', 3),
#  ('car', 3),
#  ('queen', 3),
#  ('togeth', 3),
#  ('footbal', 3),
#  ('gift', 3),
#  ('test', 3),
#  ('rocki', 3),
#  ('memori', 3),
#  ('involv', 3),
#  ('classmat', 3),
#  ('warrior', 3),
#  ('standup', 3),
#  ('nurs', 3),
#  ('machin', 3),
#  ('lover', 3),
#  ('desper', 3),
#  ('resid', 3),
#  ('teach', 2),
#  ('sneak', 2),
#  ('poland', 2),
#  ('land', 2),
#  ('prevent', 2),
#  ('steve', 2),
#  ('amish', 2),
#  ('attempt', 2),
#  ('club', 2),
#  ('inspector', 2),
#  ('desk', 2),
#  ('ruthless', 2),
#  ('caus', 2),
#  ('problem', 2),
#  ('miss', 2),
#  ('innoc', 2),
#  ('yehia', 2),
#  ('strike', 2),
#  ('intrigu', 2),
#  ('cross', 2),
#  ('path', 2),
#  ('speak', 2),
#  ('wound', 2),
#  ('surli', 2),
#  ('obsess', 2),
#  ('strang', 2),
#  ('peril', 2),
#  ('west', 2),
#  ('nasti', 2),
#  ('monster', 2),
#  ('undergo', 2),
#  ('mistak', 2),
#  ('broke', 2),
#  ('futur', 2),
#  ('heiress', 2),
#  ('author', 2),
#  ('mom', 2),
#  ('newli', 2),
#  ('evid', 2),
#  ('engin', 2),
#  ('camp', 2),
#  ('swingin', 2),
#  ('photograph', 2),
#  ('austin', 2),
#  ('diabol', 2),
#  ('steal', 2),
#  ('guid', 2),
#  ('winter', 2),
#  ('howev', 2),
#  ('match', 2),
#  ('noth', 2),
#  ('pair', 2),
#  ('sport', 2),
#  ('cash', 2),
#  ('recent', 2),
#  ('custom', 2),
#  ('guard', 2),
#  ('task', 2),
#  ('wrong', 2),
#  ('la', 2),
#  ('vega', 2),
#  ('free', 2),
#  ('launch', 2),
#  ('respons', 2),
#  ('adopt', 2),
#  ('1989', 2),
#  ('sex', 2),
#  ('late', 2),
#  ('demonstr', 2),
#  ('tackl', 2),
#  ('provoc', 2),
#  ('topic', 2),
#  ('point', 2),
#  ('captur', 2),
#  ('station', 2),
#  ('joy', 2),
#  ('bob', 2),
#  ('ross', 2),
#  ('natur', 2),
#  ('encount', 2),
#  ('parti', 2),
#  ('aspir', 2),
#  ('writer', 2),
#  ('amanda', 2),
#  ('class', 2),
#  ('card', 2),
#  ('insid', 2),
#  ('retriev', 2),
#  ('invad', 2),
#  ('benni', 2),
#  ('ho', 2),
#  ('casino', 2),
#  ('mogul', 2),
#  ('wield', 2),
#  ('threaten', 2),
#  ('empir', 2),
#  ('betray', 2),
#  ('player', 2),
#  ('alway', 2),
#  ('quirki', 2),
#  ('present', 2),
#  ('converg', 2),
#  ('know', 2),
#  ('toy', 2),
#  ('practic', 2),
#  ('episod', 2),
#  ('season', 2),
#  ('loom', 2),
#  ('forens', 2),
#  ('scienc', 2),
#  ('elit', 2),
#  ('bittersweet', 2),
#  ('duti', 2),
#  ('jake', 2),
#  ('bumbl', 2),
#  ('sidekick', 2),
#  ('african', 2),
#  ('island', 2),
#  ('legend', 2),
#  ('hold', 2),
#  ('philosoph', 2),
#  ('profound', 2),
#  ('reveal', 2),
#  ('open', 2),
#  ('emot', 2),
#  ('san', 2),
#  ('fellow', 2),
#  ('dancer', 2),
#  ('exact', 2),
#  ('joe', 2),
#  ('undercov', 2),
#  ('good', 2),
#  ('circumst', 2),
#  ('cousin', 2),
#  ('side', 2),
#  ('ancient', 2),
#  ('convict', 2),
#  ('eddi', 2),
#  ('murphi', 2),
#  ('confront', 2),
#  ('rediscov', 2),
#  ('accus', 2),
#  ('defens', 2),
#  ('reluctantli', 2),
#  ('rebellion', 2),
#  ('suddenli', 2),
#  ('prompt', 2),
#  ('combat', 2),
#  ('heir', 2),
#  ('fifteen', 2),
#  ('second', 2),
#  ('shinji', 2),
#  ('spaceship', 2),
#  ('ship', 2),
#  ('happen', 2),
#  ('ga', 2),
#  ('aim', 2),
#  ('washington', 2),
#  ('commando', 2),
#  ('plane', 2),
#  ('tough', 2),
#  ('next', 2),
#  ('street', 2),
#  ('chicago', 2),
#  ('fun', 2),
#  ('doctor', 2),
#  ('five', 2),
#  ('lone', 2),
#  ('commitment-phob', 2),
#  ('clean', 2),
#  ('unexpectedli', 2),
#  ('righteou', 2),
#  ('older', 2),
#  ('dilemma', 2),
#  ('event', 2),
#  ('brosnan', 2),
#  ('giant', 2),
#  ('franchis', 2),
#  ('hill', 2),
#  ('recount', 2),
#  ('origin', 2),
#  ('adapt', 2),
#  ('drug', 2),
#  ('unlik', 2),
#  ('reject', 2),
#  ('vietnam', 2),
#  ('eye', 2),
#  ('control', 2),
#  ('punish', 2),
#  ('shadi', 2),
#  ('turbul', 2),
#  ('shanghai', 2),
#  ('shine', 2),
#  ('motiv', 2),
#  ('god', 2),
#  ('soul', 2),
#  ('workahol', 2),
#  ('captain', 2),
#  ('spend', 2),
#  ('pay', 2),
#  ('cut', 2),
#  ('stepson', 2),
#  ('divis', 2),
#  ('found', 2),
#  ('third', 2),
#  ('cradl', 2),
#  ('bargain', 2),
#  ('go', 2),
#  ('stone', 2),
#  ('figur', 2),
#  ('flight', 2),
#  ('attend', 2),
#  ('month', 2),
#  ('intern', 2),
#  ('birth', 2),
#  ('fear', 2),
#  ('curs', 2),
#  ('rob', 2),
#  ('transform', 2),
#  ('emerg', 2),
#  ('secretli', 2),
#  ('heartbroken', 2),
#  ('instead', 2),
#  ('ken', 2),
#  ('burn', 2),
#  ('depict', 2),
#  ('restor', 2),
#  ('rel', 2),
#  ('rule', 2),
#  ('step', 2),
#  ('adulthood', 2),
#  ('band', 2),
#  ('descend', 2),
#  ('uncov', 2),
#  ('serial', 2),
#  ('domin', 2),
#  ('fame', 2),
#  ('conspiraci', 2),
#  ('biopic', 2),
#  ('tieh', 2),
#  ('person', 2),
#  ('throw', 2),
#  ('food', 2),
#  ('steer', 2),
#  ('affect', 2),
#  ('compos', 2),
#  ('musician', 2),
#  ('industri', 2),
#  ('skill', 2),
#  ('mystic', 2),
#  ('union', 2),
#  ('high-stak', 2),
#  ('solv', 2),
#  ('rooki', 2),
#  ('black', 2),
#  ('poet', 2),
#  ('pretti', 2),
#  ('deliveri', 2),
#  ('chanc', 2),
#  ('bay', 2),
#  ('blood', 2),
#  ('bride', 2),
#  ('eclect', 2),
#  ('weav', 2),
#  ('contest', 2),
#  ('politician', 2),
#  ('brothel', 2),
#  ('twist', 2),
#  ('write', 2),
#  ('room', 2),
#  ('templ', 2),
#  ('born', 2),
#  ('surviv', 2),
#  ('monitor', 2),
#  ('lord', 2),
#  ('small-tim', 2),
#  ('clip', 2),
#  ('tear', 2),
#  ('watch', 2),
#  ('boss', 2),
#  ('naiv', 2),
#  ('knew', 2),
#  ('sad', 2),
#  ('away', 2),
#  ('prize', 2),
#  ('jack', 2),
#  ('nostalg', 2),
#  ('recal', 2),
#  ('penniless', 2),
#  ('opium', 2),
#  ('guerrilla', 2),
#  ('wind', 2),
#  ('drag', 2),
#  ('draw', 2),
#  ('fli', 2),
#  ('circu', 2),
#  ('ryan', 2),
#  ('pee-we', 2),
#  ('live-act', 2),
#  ('amid', 2),
#  ('termin', 2),
#  ('suit', 2),
#  ('argentina', 2),
#  ('oliv', 2),
#  ('auschwitz', 2),
#  ('wreck', 2),
#  ('dark', 2),
#  ('tommi', 2),
#  ('crystal', 2),
#  ('altar', 2),
#  ('seem', 2),
#  ('landown', 2),
#  ('want', 2),
#  ('coach', 2),
#  ('diseas', 2),
#  ('australia', 2),
#  ('target', 2),
#  ('corrupt', 2),
#  ('gritti', 2),
#  ('torment', 2),
#  ('demon', 2),
#  ('yuppi', 2),
#  ('unusu', 2),
#  ('contend', 2),
#  ('pal', 2),
#  ('robberi', 2),
#  ('earli', 2),
#  ('egypt', 2),
#  ('soviet', 2),
#  ('rebuild', 2),
#  ('fighter', 2),
#  ('balboa', 2),
#  ('apollo', 2),
#  ('creed', 2),
#  ('retir', 2),
#  ('inspir', 2),
#  ('glori', 2),
#  ('visit', 2),
#  ('expert', 2),
#  ('nomad', 2),
#  ('religion', 2),
#  ('kinison', 2),
#  ('everi', 2),
#  ('segment', 2),
#  ('televis', 2),
#  ('sibl', 2),
#  ('enlist', 2),
#  ('ii', 2),
#  ('divid', 2),
#  ('zombi', 2),
#  ('road', 2),
#  ('hospit', 2),
#  ('confin', 2),
#  ('keep', 2),
#  ('look', 2),
#  ('coupl', 2),
#  ('treatment', 2),
#  ('armi', 2),
#  ('answer', 2),
#  ('race', 2),
#  ('cathol', 2),
#  ('manag', 2),
#  ('era', 2),
#  ('ooz', 2),
#  ('privat', 2),
#  ('dil', 2),
#  ('trigger', 2),
#  ('screen', 2),
#  ('cope', 2),
#  ('realiti', 2),
#  ('frank', 2),
#  ('drebin', 2),
#  ('energi', 2),
#  ('super', 2),
#  ('might', 2),
#  ('oil', 2),
#  ('interview', 2),
#  ('tim', 2),
#  ('allen', 2),
#  ('lawn', 2),
#  ('pageant', 2),
#  ('worm', 2),
#  ('trevor', 1),
#  ('garfield', 1),
#  ('weari', 1),
#  ('warfar', 1),
#  ('system', 1),
#  ('california', 1),
#  ('think', 1),
#  ('less', 1),
#  ('hostil', 1),
#  ('environ', 1),
#  ('dissid', 1),
#  ('refuge', 1),
#  ('denmark', 1),
#  ('center', 1),
#  ('engross', 1),
#  ('melodrama', 1),
#  ('golden', 1),
#  ('globe-nomin', 1),
#  ('debra', 1),
#  ('winger', 1),
#  ('shelter', 1),
#  ('slow-wit', 1),
#  ('aunt', 1),
#  ('franc', 1),
#  ('dri', 1),
#  ('cleaner', 1),
#  ('run-in', 1),
#  ('richard', 1),
#  ('grieco', 1),
#  ('dimwit', 1),
#  ('doug', 1),
#  ('entri', 1),
#  ('swanki', 1),
#  ('nightclub', 1),
#  ('saturday', 1),
#  ('reckless', 1),
#  ('prosecutor', 1),
#  ('youth', 1),
#  ('condemn', 1),
#  ('commun', 1),
#  ('promot', 1),
#  ('woo', 1),
#  ('glamor', 1),
#  ('clue', 1),
#  ('mayhem', 1),
#  ('matter', 1),
#  ('technic', 1),
#  ('kindli', 1),
#  ('jimmi', 1),
#  ('goon', 1),
#  ('jyoti', 1),
#  ('indirectli', 1),
#  ('reve', 1),
#  ('walsh', 1),
#  ('fought', 1),
#  ('awar', 1),
#  ('pursuit', 1),
#  ('repar', 1),
#  ('great', 1),
#  ('cost', 1),
#  ('peak', 1),
#  ('hunger', 1),
#  ('smitten', 1),
#  ('creativ', 1),
#  ('crisi', 1),
#  ('muse', 1),
#  ('simpl', 1),
#  ('thrown', 1),
#  ('web', 1),
#  ('bandit', 1),
#  ('canin', 1),
#  ('con', 1),
#  ('tightli', 1),
#  ('unfulfil', 1),
#  ('neo-nazi', 1),
#  ('footstep', 1),
#  ('immigr', 1),
#  ('america', 1),
#  ('sometim', 1),
#  ('countri', 1),
#  ('felin', 1),
#  ('mouse-nap', 1),
#  ('spree', 1),
#  ('bottom', 1),
#  ('surgeri', 1),
#  ('reflect', 1),
#  ('courtroom', 1),
#  ('concret', 1),
#  ('stun', 1),
#  ('nearbi', 1),
#  ('structur', 1),
#  ('sour', 1),
#  ('obsessive-compuls', 1),
#  ('crumbl', 1),
#  ('stressed-out', 1),
#  ('singl', 1),
#  ('kgb', 1),
#  ('file', 1),
#  ('expos', 1),
#  ('architect', 1),
#  ('conspir', 1),
#  ('build', 1),
#  ('design', 1),
#  ('genocid', 1),
#  ('fashion', 1),
#  ('groovi', 1),
#  ('sinist', 1),
#  ('geniu', 1),
#  ('mojo', 1),
#  ('fast-pac', 1),
#  ('miami', 1),
#  ('narcot', 1),
#  ('hot', 1),
#  ('trail', 1),
#  ('snatch', 1),
#  ('100', 1),
#  ('million', 1),
#  ('worth', 1),
#  ('balto', 1),
#  ('half', 1),
#  ('wolf', 1),
#  ('dog', 1),
#  ('taunt', 1),
#  ('disapprov', 1),
#  ('preciou', 1),
#  ('cargo', 1),
#  ('medicin', 1),
#  ('alaskan', 1),
#  ('naïv', 1),
#  ('stepfath', 1),
#  ('approv', 1),
#  ('split', 1),
#  ('slacker', 1),
#  ('made-up', 1),
#  ('baseketbal', 1),
#  ('craze', 1),
#  ('basketball/basebal', 1),
#  ('hybrid', 1),
#  ('novelist', 1),
#  ('mirror', 1),
#  ('tradit', 1),
#  ('promis', 1),
#  ('expatri', 1),
#  ('disaster-pron', 1),
#  ('bean', 1),
#  ('unfit', 1),
#  ('physic', 1),
#  ('boob', 1),
#  ('tube', 1),
#  ('gone', 1),
#  ('beavi', 1),
#  ('butt-head', 1),
#  ('expedit', 1),
#  ('capit', 1),
#  ('ladi', 1),
#  ('robin', 1),
#  ('jamika', 1),
#  ('heel', 1),
#  ('greet', 1),
#  ('bebe', 1),
#  ('grant', 1),
#  ('superhero', 1),
#  ('overgrown', 1),
#  ('adolesc', 1),
#  ('sonni', 1),
#  ('koufax', 1),
#  ('5-year-old', 1),
#  ('grownup', 1),
#  ('rememb', 1),
#  ('view', 1),
#  ('puf', 1),
#  ('cigarett', 1),
#  ('smoke', 1),
#  ('weed', 1),
#  ('drink', 1),
#  ('commerci', 1),
#  ...]

# %%
sorted(before_1980.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('world', 12),
#  ('war', 12),
#  ('new', 10),
#  ('woman', 9),
#  ('find', 9),
#  ('film', 8),
#  ('fall', 8),
#  ('life', 8),
#  ('love', 7),
#  ('famili', 7),
#  ('friend', 7),
#  ('tri', 6),
#  ('young', 6),
#  ('one', 6),
#  ('get', 6),
#  ('take', 6),
#  ('forc', 5),
#  ('ii', 5),
#  ('father', 5),
#  ('wife', 5),
#  ('daughter', 5),
#  ('girl', 5),
#  ('past', 5),
#  ('documentari', 5),
#  ('offic', 5),
#  ('town', 5),
#  ('man', 5),
#  ('fight', 5),
#  ('director', 4),
#  ('live', 4),
#  ('teen', 4),
#  ('american', 4),
#  ('plot', 4),
#  ('transform', 4),
#  ('secret', 4),
#  ('danger', 4),
#  ('follow', 4),
#  ('music', 4),
#  ('soon', 4),
#  ('lead', 4),
#  ('prepar', 4),
#  ('return', 4),
#  ('hire', 4),
#  ('captur', 4),
#  ('join', 4),
#  ('two', 4),
#  ('polic', 4),
#  ('time', 4),
#  ('nazi', 4),
#  ('becom', 4),
#  ('drama', 3),
#  ('alli', 3),
#  ('dark', 3),
#  ('grow', 3),
#  ('give', 3),
#  ('enemi', 3),
#  ('leav', 3),
#  ('four', 3),
#  ('america', 3),
#  ('citi', 3),
#  ('deadli', 3),
#  ('high', 3),
#  ('adapt', 3),
#  ('reach', 3),
#  ('mistress', 3),
#  ('children', 3),
#  ('professor', 3),
#  ('agent', 3),
#  ('way', 3),
#  ('prison', 3),
#  ('british', 3),
#  ('home', 3),
#  ('beauti', 3),
#  ('island', 3),
#  ('hand', 3),
#  ('classic', 3),
#  ('forbidden', 3),
#  ('fill', 3),
#  ('work', 3),
#  ('marri', 3),
#  ('john', 3),
#  ('hit', 3),
#  ('comedi', 3),
#  ('learn', 3),
#  ('track', 3),
#  ('send', 3),
#  ('footag', 3),
#  ('combat', 3),
#  ('black', 3),
#  ('evil', 3),
#  ('murder', 3),
#  ('keep', 3),
#  ('itali', 3),
#  ('python', 3),
#  ('group', 3),
#  ('order', 3),
#  ('resort', 3),
#  ('frank', 3),
#  ('student', 3),
#  ('turn', 3),
#  ('champ', 3),
#  ('crew', 3),
#  ('protect', 3),
#  ('wartim', 2),
#  ('win', 2),
#  ('dream', 2),
#  ('make', 2),
#  ('singl', 2),
#  ('start', 2),
#  ('befriend', 2),
#  ('romanc', 2),
#  ('handsom', 2),
#  ('anoth', 2),
#  ('blood', 2),
#  ('age', 2),
#  ('king', 2),
#  ('kingdom', 2),
#  ('cousin', 2),
#  ('talent', 2),
#  ('vanish', 2),
#  ('along', 2),
#  ('1967', 2),
#  ('exist', 2),
#  ('line', 2),
#  ('tour', 2),
#  ('benji', 2),
#  ('goe', 2),
#  ('save', 2),
#  ('christma', 2),
#  ('strict', 2),
#  ('wealthi', 2),
#  ('parent', 2),
#  ('poor', 2),
#  ('christian', 2),
#  ('fisherman', 2),
#  ('run', 2),
#  ('taylor', 2),
#  ('killer', 2),
#  ('terror', 2),
#  ('power', 2),
#  ('school', 2),
#  ('``', 2),
#  ('torment', 2),
#  ('clan', 2),
#  ('favor', 2),
#  ('die', 2),
#  ('stage', 2),
#  ('businessman', 2),
#  ('decid', 2),
#  ('version', 2),
#  ('timeless', 2),
#  ('stori', 2),
#  ('travel', 2),
#  ('magic', 2),
#  ('fli', 2),
#  ('even', 2),
#  ('lord', 2),
#  ('part', 2),
#  ('stop', 2),
#  ('seek', 2),
#  ('dealer', 2),
#  ('end', 2),
#  ('camp', 2),
#  ('volunt', 2),
#  ('guard', 2),
#  ('german', 2),
#  ('invas', 2),
#  ('absenc', 2),
#  ('away', 2),
#  ('epic', 2),
#  ('build', 2),
#  ('la', 2),
#  ('fellow', 2),
#  ('ring', 2),
#  ('master', 2),
#  ('brutal', 2),
#  ('crime', 2),
#  ('chronicl', 2),
#  ('trial', 2),
#  ('peasant', 2),
#  ('three', 2),
#  ('emperor', 2),
#  ('reign', 2),
#  ('heroic', 2),
#  ('outlaw', 2),
#  ('femal', 2),
#  ('loyalti', 2),
#  ('quest', 2),
#  ('target', 2),
#  ('want', 2),
#  ('star', 2),
#  ('starship', 2),
#  ('captain', 2),
#  ('good', 2),
#  ('bond', 2),
#  ('best', 2),
#  ('examin', 2),
#  ('psycholog', 2),
#  ('led', 2),
#  ('rise', 2),
#  ('antholog', 2),
#  ('discuss', 2),
#  ('perform', 2),
#  ('holi', 2),
#  ('showdown', 2),
#  ('cop', 2),
#  ('aim', 2),
#  ('histori', 2),
#  ('japan', 2),
#  ('centuri', 2),
#  ('villag', 2),
#  ('teenag', 2),
#  ('set', 2),
#  ('fortress', 2),
#  ('act', 2),
#  ('job', 2),
#  ('street', 2),
#  ('york', 2),
#  ('gambler', 2),
#  ('monti', 2),
#  ('tabl', 2),
#  ('far', 2),
#  ('wide', 2),
#  ('absurd', 2),
#  ('tv', 2),
#  ('player', 2),
#  ('mark', 2),
#  ('certain', 2),
#  ('ship', 2),
#  ('capt', 2),
#  ('liber', 2),
#  ('includ', 2),
#  ('hope', 2),
#  ('buddi', 2),
#  ('kill', 2),
#  ('collect', 2),
#  ('featur', 2),
#  ('groundbreak', 2),
#  ('african', 2),
#  ('women', 2),
#  ('left', 2),
#  ('capra', 2),
#  ('germani', 2),
#  ('defens', 2),
#  ('better', 2),
#  ('assum', 2),
#  ('grad', 2),
#  ('need', 2),
#  ('money', 2),
#  ('must', 2),
#  ('old', 2),
#  ('boyfriend', 2),
#  ('arriv', 2),
#  ('year', 2),
#  ('jail', 2),
#  ('rocki', 2),
#  ('balboa', 2),
#  ('apollo', 2),
#  ('creed', 2),
#  ('childhood', 2),
#  ('unawar', 2),
#  ('campaign', 2),
#  ('soldier', 2),
#  ('sing', 2),
#  ('sister', 2),
#  ('lose', 2),
#  ('thug', 2),
#  ('put', 2),
#  ('togeth', 2),
#  ('last', 2),
#  ('cab', 2),
#  ('driver', 2),
#  ('sheriff', 2),
#  ('center', 2),
#  ('look', 2),
#  ('small', 2),
#  ('battl', 2),
#  ('competit', 2),
#  ('ensu', 2),
#  ('five', 2),
#  ('former', 2),
#  ('command', 2),
#  ('use', 2),
#  ('pursu', 2),
#  ('bomb', 2),
#  ('enlist', 2),
#  ('insid', 2),
#  ('come', 2),
#  ('host', 2),
#  ('seri', 2),
#  ('aid', 2),
#  ('troop', 2),
#  ('ii-era', 2),
#  ('detail', 1),
#  ('pivot', 1),
#  ('day', 1),
#  ('1944', 1),
#  ('task', 1),
#  ('seiz', 1),
#  ('control', 1),
#  ('key', 1),
#  ('bridg', 1),
#  ('holland', 1),
#  ('satir', 1),
#  ('stanley', 1),
#  ('kubrick', 1),
#  ('viciou', 1),
#  ('sociopath', 1),
#  ('dystopian', 1),
#  ('england', 1),
#  ('undergo', 1),
#  ('experiment', 1),
#  ('rehabilit', 1),
#  ('therapi', 1),
#  ('alexandria', 1),
#  ('egyptian', 1),
#  ('enamor', 1),
#  ('hollywood', 1),
#  ('widow', 1),
#  ('singer', 1),
#  ('mother', 1),
#  ('diner', 1),
#  ('waitress', 1),
#  ('arizona', 1),
#  ('cowork', 1),
#  ('ruggedli', 1),
#  ('rancher', 1),
#  ('abandon', 1),
#  ('park', 1),
#  ('amar', 1),
#  ('akbar', 1),
#  ('anthoni', 1),
#  ('independ', 1),
#  ('knowledg', 1),
#  ('reunit', 1),
#  ('adult', 1),
#  ('coincid', 1),
#  ('hospit', 1),
#  ('buddha', 1),
#  ('philosophi', 1),
#  ('nonviol', 1),
#  ('warmong', 1),
#  ('destruct', 1),
#  ('rescu', 1),
#  ('heirless', 1),
#  ('maharaj', 1),
#  ('brajbhan', 1),
#  ('throne', 1),
#  ('vikram', 1),
#  ('badi', 1),
#  ('rani', 1),
#  ('final', 1),
#  ('conceiv', 1),
#  ('destroy', 1),
#  ('dysfunct', 1),
#  ('middle-class', 1),
#  ('attent', 1),
#  ('chef', 1),
#  ('valuabl', 1),
#  ('jewel', 1),
#  ('aftermath', 1),
#  ('arab-isra', 1),
#  ('lebanes', 1),
#  ('navig', 1),
#  ('rapidli', 1),
#  ('polit', 1),
#  ('press', 1),
#  ('behind', 1),
#  ('scene', 1),
#  ('santa', 1),
#  ('workshop', 1),
#  ('devast', 1),
#  ('raj', 1),
#  ('son', 1),
#  ('bobbi', 1),
#  ('oppos', 1),
#  ('bonni', 1),
#  ('parker', 1),
#  ('clyde', 1),
#  ('barrow', 1),
#  ('bullet-riddl', 1),
#  ('bank', 1),
#  ('robberi', 1),
#  ('spree', 1),
#  ('across', 1),
#  ('depression-ravag', 1),
#  ('elizabeth', 1),
#  ('oscar', 1),
#  ('gloria', 1),
#  ('wandrou', 1),
#  ('stylish', 1),
#  ('call', 1),
#  ('yearn', 1),
#  ('go', 1),
#  ('straight', 1),
#  ('especi', 1),
#  ('think', 1),
#  ('found', 1),
#  ('mr.', 1),
#  ('right', 1),
#  ('cairo', 1),
#  ('newsstand', 1),
#  ('vendor', 1),
#  ('fantasi', 1),
#  ('morph', 1),
#  ('fixat', 1),
#  ('lemonad', 1),
#  ('seller', 1),
#  ('serial', 1),
#  ('begin', 1),
#  ('outcast', 1),
#  ('telekinet', 1),
#  ('abil', 1),
#  ('lash', 1),
#  ('crowd', 1),
#  ('sick', 1),
#  ('joke', 1),
#  ('prom', 1),
#  ('member', 1),
#  ('southern', 1),
#  ('scrambl', 1),
#  ('curri', 1),
#  ('patriarch', 1),
#  ('tennesse', 1),
#  ('william', 1),
#  ('sizzl', 1),
#  ('40th', 1),
#  ('birthday', 1),
#  ('egotist', 1),
#  ('kick', 1),
#  ('midlif', 1),
#  ('crisi', 1),
#  ('secur', 1),
#  ('adventur', 1),
#  ('wilbur', 1),
#  ('pig', 1),
#  ('templeton', 1),
#  ('rat', 1),
#  ('charlott', 1),
#  ('spider', 1),
#  ('anim', 1),
#  ('e.b', 1),
#  ('white', 1),
#  ('quirki', 1),
#  ('inventor', 1),
#  ('caractacu', 1),
#  ('pott', 1),
#  ('car', 1),
#  ('vulgaria', 1),
#  ('strang', 1),
#  ('devoid', 1),
#  ('jealou', 1),
#  ('regard', 1),
#  ('hold', 1),
#  ('brother-in-law', 1),
#  ('botani', 1),
#  ('elabor', 1),
#  ('prank', 1),
#  ('score', 1),
#  ('stylin', 1),
#  ('special', 1),
#  ('chase', 1),
#  ('drug', 1),
#  ('traffick', 1),
#  ('reveng', 1),
#  ('luke', 1),
#  ('jackson', 1),
#  ('like', 1),
#  ('thing', 1),
#  ('hurt', 1),
#  ('wrong', 1),
#  ('side', 1),
#  ('warden', 1),
#  ('belov', 1),
#  ('sitcom', 1),
#  ('unlik', 1),
#  ('hero', 1),
#  ('three-year', 1),
#  ('drift', 1),
#  ('sailor', 1),
#  ('feud', 1),
#  ('commun', 1),
#  ('unravel', 1),
#  ('physician', 1),
#  ('swept', 1),
#  ('bolshevik', 1),
#  ('revolut', 1),
#  ('oscar-win', 1),
#  ('el', 1),
#  ('chavo', 1),
#  ('nameless', 1),
#  ('orphan', 1),
#  ('apart', 1),
#  ('chilindrina', 1),
#  ('quico', 1),
#  ('doña', 1),
#  ('florinda', 1),
#  ('ramón', 1),
#  ('jirafal', 1),
#  ('journalist', 1),
#  ('naresh', 1),
#  ('probe', 1),
#  ('illeg', 1),
#  ('activ', 1),
#  ('recruit', 1),
#  ('shaolin', 1),
#  ('lee', 1),
#  ('infiltr', 1),
#  ('remot', 1),
#  ('martial', 1),
#  ('art', 1),
#  ('tournament', 1),
#  ('spi', 1),
#  ('sinist', 1),
#  ('jewish', 1),
#  ('strong-wil', 1),
#  ('pre-revolutionari', 1),
#  ('russia', 1),
#  ('expand', 1),
#  ('teng', 1),
#  ('squad', 1),
#  ('rebel', 1),
#  ('whose', 1),
#  ('leader', 1),
#  ('torn', 1),
#  ('owner', 1),
#  ('separ', 1),
#  ('greec', 1),
#  ('variou', 1),
#  ('bad', 1),
#  ('guy', 1),
#  ('pulp-fict', 1),
#  ('sci-fi', 1),
#  ('planet', 1),
#  ('lesli', 1),
#  ('nielsen', 1),
#  ('paradis', 1),
#  ('altair-iv', 1),
#  ('gigi', 1),
#  ('avant-gard', 1),
#  ('french', 1),
#  ('waif', 1),
#  ('groom', 1),
#  ('de', 1),
#  ('joie', 1),
#  ('affluent', 1),
#  ('gaston', 1),
#  ('metamorphos', 1),
#  ('stun', 1),
#  ('circumst', 1),
#  ('compel', 1),
#  ('ram', 1),
#  ('pretend', 1),
#  ('twin', 1),
#  ('lie', 1),
#  ('boss', 1),
#  ('fictiti', 1),
#  ('brother', 1),
#  ('travolta', 1),
#  ('olivia', 1),
#  ('newton-john', 1),
#  ('greaser', 1),
#  ('much', 1),
#  ('chagrin', 1),
#  ('crook', 1),
#  ('threaten', 1),
#  ('tragic', 1),
#  ('adolf', 1),
#  ('hitler', 1),
#  ('manipul', 1),
#  ('image-mak', 1),
#  ('humbl', 1),
#  ('origin', 1),
#  ('near-world', 1),
#  ('conquest', 1),
#  ('motiv', 1),
#  ('strive', 1),
#  ('dishwash', 1),
#  ('waiter', 1),
#  ('luxuri', 1),
#  ('hotel', 1),
#  ('tread', 1),
#  ('abus', 1),
#  ('tide', 1),
#  ('workplac', 1),
#  ('hierarchi', 1),
#  ('illustr', 1),
#  ('natur', 1),
#  ('desir', 1),
#  ('incest', 1),
#  ('bloodlust', 1),
#  ('subject', 1),
#  ('mistrust', 1),
#  ('cagey', 1),
#  ('tailor', 1),
#  ('whereabout', 1),
#  ('doctor', 1),
#  ('mind', 1),
#  ('abyss', 1),
#  ('jimi', 1),
#  ('hendrix', 1),
#  ('musician', 1),
#  ('influenc', 1),
#  ('also', 1),
#  ('appear', 1),
#  ('band', 1),
#  ('pilgrimag', 1),
#  ('countri', 1),
#  ('boy', 1),
#  ('chang', 1),
#  ('violent', 1),
#  ('ahead', 1),
#  ('author', 1),
#  ('craze', 1),
#  ('blaze', 1),
#  ('trail', 1),
#  ('anxiou', 1),
#  ('harden', 1),
#  ('mean', 1),
#  ('remak', 1),
#  ('dirti', 1),
#  ('harri', 1),
#  ('though', 1),
#  ('cultur', 1),
#  ('insensit', 1),
#  ('modern', 1),
#  ('standard', 1),
#  ('propaganda', 1),
#  ('16th', 1),
#  ('1930', 1),
#  ('speech', 1),
#  ('hearing-impair', 1),
#  ('coupl', 1),
#  ('persist', 1),
#  ('unforgiv', 1),
#  ('obstacl', 1),
#  ('accept', 1),
#  ('societi', 1),
#  ('digniti', 1),
#  ('vain', 1),
#  ('self-right', 1),
#  ('nobleman', 1),
#  ('ideal', 1),
#  ('veteran', 1),
#  ('suffer', 1),
#  ('scar', 1),
#  ('physic', 1),
#  ('patient', 1),
#  ('staff', 1),
#  ('treatment', 1),
#  ('23rd', 1),
#  ('inhabit', 1),
#  ('dome', 1),
#  ('pleasur', 1),
#  ('allow', 1),
#  ('30', 1),
#  ('english', 1),
#  ('landladi', 1),
#  ('closer', 1),
#  ('obsess', 1),
#  ('lupin', 1),
#  ('sidekick', 1),
#  ('jigen', 1),
#  ('samurai', 1),
#  ('warrior', 1),
#  ('goemon', 1),
#  ('counterfeit', 1),
#  ('oper', 1),
#  ('count', 1),
#  ('cagliostro', 1),
#  ('post-apocalypt', 1),
#  ('futur', 1),
#  ('malici', 1),
#  ('gang', 1),
#  ('max', 1),
#  ('retali', 1),
#  ('open', 1),
#  ('road', 1),
#  ('vengeanc', 1),
#  ('fire', 1),
#  ('connect', 1),
#  ('prostitut', 1),
#  ('met', 1),
#  ('red-light', 1),
#  ('district', 1),
#  ('littl', 1),
#  ('low-level', 1),
#  ('hoodlum', 1),
#  ('wrestl', 1),
#  ('mobster', 1),
#  ('uncl', 1),
#  ('faith', 1),
#  ('friendship', 1),
#  ('inveter', 1),
#  ('skewer', 1),
#  ('arthur', 1),
#  ('knight', 1),
#  ('round', 1),
#  ('grail', 1),
#  ('elev', 1),
#  ('height', 1),
#  ('bring', 1),
#  ('sketch', 1),
#  ('phonet', 1),
#  ('australian', 1),
#  ('accent', 1),
#  ('mix', 1),
#  ('wit', 1),
#  ('ingenu', 1),
#  ('brilliant', 1),
#  ('penchant', 1),
#  ('mockeri', 1),
#  ('cross-dress', 1),
#  ('born', 1),
#  ('stabl', 1),
#  ('judea', 1),
#  ('brian', 1),
#  ('anti-roman', 1),
#  ('zealot', 1),
#  ('fate', 1),
#  ('confus', 1),
#  ('carpent', 1),
#  ('marlon', 1),
#  ('brando', 1),
#  ('nuanc', 1),
#  ('aristocrat', 1),
#  ('lt.', 1),
#  ('fletcher', 1),
#  ('aboard', 1),
#  ('hm', 1),
#  ('bounti', 1),
#  ('mutini', 1),
#  ('tyrann', 1),
#  ('bligh', 1),
#  ('shock', 1),
#  ('show', 1),
#  ('concentr', 1),
#  ('buchenwald', 1),
#  ('ohrdruf', 1),
#  ('gen.', 1),
#  ('eisenhow', 1),
#  ('local', 1),
#  ('prevent', 1),
#  ('skip', 1),
#  ('rowdi', 1),
#  ('sibl', 1),
#  ('measur', 1),
#  ('sinatra', 1),
#  ('all-star', 1),
#  ('cast', 1),
#  ('danni', 1),
#  ('ocean', 1),
#  ('knock', 1),
#  ('casino', 1),
#  ('vega', 1),
#  ('strip', 1),
#  ('spaghetti', 1),
#  ('western', 1),
#  ('flinti', 1),
#  ('gunsling', 1),
#  ('railroad', 1),
#  ('tycoon', 1),
#  ('anyon', 1),
#  ('stand', 1),
#  ('trans-american', 1),
#  ('iron', 1),
#  ('hors', 1),
#  ('newli', 1),
#  ('preserv', 1),
#  ('20', 1),
#  ('made', 1),
#  ('audienc', 1),
#  ('1915', 1),
#  ('1946', 1),
#  ('restor', 1),
#  ('tackl', 1),
#  ('hot-button', 1),
#  ('issu', 1),
#  ('transcend', 1),
#  ('norm', 1),
#  ('cinema', 1),
#  ('industri', 1),
#  ('authoritarian', 1),
#  ('liberti', 1),
#  ('spoil', 1),
#  ('princ', 1),
#  ('temporarili', 1),
#  ('common', 1),
#  ('ident', 1),
#  ('palac', 1),
#  ('gift', 1),
#  ('colleg', 1),
#  ('disguis', 1),
#  ('tutor', 1),
#  ('watch', 1),
#  ('eye', 1),
#  ('aunt', 1),
#  ('delhi', 1),
#  ('interview', 1),
#  ('mumbai', 1),
#  ('reconnect', 1),
#  ('flame', 1),
#  ('still', 1),
#  ('feel', 1),
#  ('jim', 1),
#  ('stark', 1),
#  ('troubl', 1),
#  ('firmli', 1),
#  ('tow', 1),
#  ('quickli', 1),
#  ('next', 1),
#  ('door', 1),
#  ('vulner', 1),
#  ('plato', 1),
#  ('freed', 1),
#  ('spend', 1),
#  ('12', 1),
#  ('homecom', 1),
#  ('affair', 1),
#  ('disillus', 1),
#  ('clash', 1),
#  ('expect', 1),
#  ('richard', 1),
#  ('pryor', 1),
#  ('1979', 1),
#  ('concert', 1),
#  ('rang', 1),
#  ('topic', 1),
#  ('race', 1),
#  ('favorit', 1),
#  ('sylvest', 1),
#  ('stallon', 1),
#  ('shot', 1),
#  ('fame', 1),
#  ('unknown', 1),
#  ('fighter', 1),
#  ('given', 1),
#  ('public', 1),
#  ('stunt', 1),
#  ('rous', 1),
#  ('climax', 1),
#  ('engag', 1),
#  ('sequel', 1),
#  ('boxer', 1),
#  ('rematch', 1),
#  ('thrill', 1),
#  ('pregnant', 1),
#  ('belli', 1),
#  ('unborn', 1),
#  ('child', 1),
#  ('seriou', 1),
#  ('close', 1),
#  ('drastic', 1),
#  ('differ', 1),
#  ('path', 1),
#  ('meet', 1),
#  ('chanc', 1),
#  ('later', 1),
#  ('sultan', 1),
#  ('egypt', 1),
#  ('syria', 1),
#  ('launch', 1),
#  ('retak', 1),
#  ('jerusalem', 1),
#  ('amid', 1),
#  ('crusad', 1),
#  ('invad', 1),
#  ('liri', 1),
#  ('valley', 1),
#  ('san', 1),
#  ('pietro', 1),
#  ('exampl', 1),
#  ('effect', 1),
#  ('civilian', 1),
#  ('dead', 1),
#  ('pilot', 1),
#  ('wed', 1),
#  ('long', 1),
#  ('plan', 1),
#  ('marshal', 1),
#  ('move', 1),
#  ('back', 1),
#  ('hometown', 1),
#  ('rent', 1),
#  ('properti', 1),
#  ('refus', 1),
#  ('affect', 1),
#  ('employe', 1),
#  ('disappear', 1),
#  ('singapor', 1),
#  ('shyam', 1),
#  ('india', 1),
#  ('investig', 1),
#  ('entangl', 1),
#  ('1950', 1),
#  ('harlem', 1),
#  ('big', 1),
#  ('melodrama', 1),
#  ('inspir', 1),
#  ('suprem', 1),
#  ('unflapp', 1),
#  ('kirk', 1),
#  ('enterpris', 1),
#  ('delv', 1),
#  ('deep', 1),
#  ('space', 1),
#  ('explor', 1),
#  ('civil', 1),
#  ('cocain', 1),
#  ('youngblood', 1),
#  ('priest', 1),
#  ('deal', 1),
#  ('net', 1),
#  ('enough', 1),
#  ('enter', 1),
#  ('arrang', 1),
#  ('marriag', 1),
#  ('spirit', 1),
#  ('intellectu', 1),
#  ('adjust', 1),
#  ('choic', 1),
#  ('enrag', 1),
#  ('moral', 1),
#  ('rot', 1),
#  ('urban', 1),
#  ('decay', 1),
#  ('unhing', 1),
#  ('mad', 1),
#  ('assassin', 1),
#  ('sex', 1),
#  ('worker', 1),
#  ('homespun', 1),
#  ('humor', 1),
#  ('easygo', 1),
#  ('andi', 1),
#  ('nostalg', 1),
#  ('mayberri', 1),
#  ('lovabl', 1),
#  ('charact', 1),
#  ('ford', 1),
#  ('midway', 1),
#  ('air', 1),
#  ('sea', 1),
#  ('point', 1),
#  ('pacif', 1),
#  ('sugar', 1),
#  ('cane', 1),
#  ('produc', 1),
#  ('greedi', 1),
#  ('landlord', 1),
#  ('conspir', 1),
#  ('agricultur', 1),
#  ('engin', 1),
#  ('southwestern', 1),
#  ('wade', 1),
#  ('peopl', 1),
#  ('via', 1),
#  ('mysteri', 1),
#  ('driverless', 1),
#  ('sedan', 1),
#  ('depression-era', 1),
#  ('orlean', 1),
#  ('cocksur', 1),
#  ('stud', 1),
#  ('poker', 1),
#  ('eric', 1),
#  ('stoner', 1),
#  ('titular', 1),
#  ('cincinnati', 1),
#  ('kid', 1),
#  ('challeng', 1),
#  ('longtim', 1),
#  ('lancey', 1),
#  ('howard', 1),
#  ('will', 1),
#  ('nerv', 1),
#  ('pleasant', 1),
#  ('cruis', 1),
#  ('mistak', 1),
#  ('mischiev', 1),
#  ('stowaway', 1),
#  ('entertain', 1),
#  ('wild', 1),
#  ('wacki', 1),
#  ('hijink', 1),
#  ('kung', 1),
#  ('fu', 1),
#  ('pupil', 1),
#  ('qing-dynasti', 1),
#  ('china', 1),
#  ('weapon', 1),
#  ('invent', 1),
#  ('distanc', 1),
#  ('without', 1),
#  ('trace', 1),
#  ('wielder', 1),
#  ('unwittingli', 1),
#  ('skill', 1),
#  ('obtain', 1),
#  ('militari', 1),
#  ...]

# %% [markdown]
# In each different time frame, we see very similar words used most. Since 1980, the categories seem near identical. Before then, we see it's similar, but the lack of data perhaps takes from the accuracy. The words 'young', 'love' and 'life' among many other appear very frequently, especially since 1980. Before 1980, we see that there are 12 movies/tv shows with 'world' in and 12 films with 'war' in, these being the most common words suggests that in this era many of the films were world war based. This is backed up with several other war-based words coming up for example there are 4 occurrences of 'pilot', 'nazi', 'capture' and 'secret'. Let's look at this further.

# %%
potential_war_films = []
for i in range(len(netflix_data_2)):
    if netflix_data_2[['release_year']].iloc[i,0] < 1980:
        text = netflix_data_2[['description']].iloc[i,0]
        if 'war' in text:
            potential_war_films.append(netflix_data_2[['description']].iloc[i,0])           
    else:
        continue

# %%
potential_war_films
# Out:
# ['This wartime drama details a pivotal day in 1944 when an Allied task force tried to win World War II by seizing control of key bridges in Holland.',
#  'In the age of Buddha and his philosophy of nonviolence, a warmonger king plots the destruction of an enemy kingdom to rescue the woman he loves.',
#  'Luke Jackson likes to do things his own way, which leads to a world of hurt when he ends up in a prison camp – and on the wrong side of its warden.',
#  "Lupin, his sidekick, Jigen, and the samurai warrior Goemon set out to take over an evil counterfeit operation at Count Cagliostro's fortress.",
#  'Two close childhood friends take drastically different paths in life, but meet by chance years later and fall in love, unaware of their past bond.',
#  'Returning home from war after being assumed dead, a pilot weds the woman he has long loved, unaware that she had been planning to marry his best friend.',
#  'Director John Ford captures combat footage of the Battle of Midway, an air and sea campaign that was a turning point in the war in the Pacific.',
#  'In Depression-era New Orleans, cocksure stud poker player Eric Stoner – the titular Cincinnati Kid – challenges longtime champ Lancey "The Man" Howard to a showdown at the table, where a war of wills – and nerve – ensues.',
#  'From wartime drafts to evening gowns, this candid time capsule documents a 1967 beauty pageant that offers an inside look at competitive drag.',
#  'After the 1978 Israeli invasion of Lebanon, children try to sing the national anthem as citizens search for hope in the war-torn South.',
#  'Two war buddies fall for two sisters and follow the girls to a resort owned by their former commanding officer, who is in danger of losing the place.']

# %% [markdown]
# While not all these films are war based, many are indicating that they use to constitute a higher percentage of the films made than they are now.

# %% [markdown]
# ### (b)

# %%
pair_publication_count = {}  
for row in range(len(netflix_data_2)):
    cast = str(netflix_data_2[['cast']].iloc[row,0]).split(', ')
    director = str(netflix_data_2[['director']].iloc[row,0]).split(', ')
    crew = cast + director
    crew = list(dict.fromkeys(crew)) # Remove duplicates in the case someone acts and directs the same show
    for person_1 in crew:                             
        for person_2 in crew:
            if person_1 < person_2:    # This assures there are no duplicate pairs :
                    
                pair_forward = (person_1, person_2)
                pair_backwards = (person_2, person_1) 
                if person_1 == 'nan' or person_2 == 'nan': # A number of rows have missing values, this gets rid of them
                    continue
                elif pair_forward in pair_publication_count:      
                    pair_publication_count[pair_forward] += 1  
                elif pair_backwards in pair_publication_count:   
                    pair_publication_count[pair_backwards] += 1   
                else:                                                                   
                    pair_publication_count[pair_forward] = 1

# %%
sorted(pair_publication_count.items(), key=lambda x: x[1], reverse=True)[0:25]
# Out:
# [(('Jan Suter', 'Raúl Campos'), 19),
#  (('John Paul Tremblay', 'Robb Wells'), 15),
#  (('John Cleese', 'Terry Jones'), 14),
#  (('John Cleese', 'Michael Palin'), 14),
#  (('Eric Idle', 'John Cleese'), 14),
#  (('Eric Idle', 'Terry Jones'), 14),
#  (('Eric Idle', 'Michael Palin'), 14),
#  (('Michael Palin', 'Terry Jones'), 14),
#  (('Jamie Watson', 'Michela Luci'), 13),
#  (('Eric Peterson', 'Michela Luci'), 13),
#  (('Eric Peterson', 'Jamie Watson'), 13),
#  (('Alessandro Juliani', 'Vincent Tong'), 13),
#  (('Graham Chapman', 'John Cleese'), 13),
#  (('Graham Chapman', 'Terry Jones'), 13),
#  (('Graham Chapman', 'Michael Palin'), 13),
#  (('John Cleese', 'Terry Gilliam'), 13),
#  (('Eric Idle', 'Graham Chapman'), 13),
#  (('Eric Idle', 'Terry Gilliam'), 13),
#  (('Terry Gilliam', 'Terry Jones'), 13),
#  (('Michael Palin', 'Terry Gilliam'), 13),
#  (('Daisuke Ono', 'Yuki Kaji'), 12),
#  (('Diana Kaarina', 'Vincent Tong'), 12),
#  (('Anna Claire Bartlam', 'Michela Luci'), 12),
#  (('Anna Claire Bartlam', 'Jamie Watson'), 12),
#  (('Anna Claire Bartlam', 'Eric Peterson'), 12)]

# %% [markdown]
# We see that many of the people that appear in this list appear more than once. For example, Eric Idle, John Cleese and Michael Palin have all been in 14 shows with each other. This is because they have continually worked together as a group (Monty Python). I'd imagine this is like the other groups of names that appear in this list together.

# %% [markdown]
# ### (c)
#
# For my analysis, I will be finding the distribution of film lengths, and then comparing the average film lengths of films from various countries.

# %%
movies = netflix_data_2[netflix_data_2.type == 'Movie']

# %%
def length_distribution(data):
    lengths = pd.DataFrame(np.zeros((320, 1)))
    lengths = lengths.rename(columns = {0:'Freq'})
    for i in range(len(data)):
        length = data[['duration']].iloc[i,0]
        length = length.split(' ')
        length = int(length[0])
        lengths.iloc[[length]] += 1
    lengths['Freq'][2]
    lengths.index
    lengths['Density'] = lengths['Freq'] / lengths['Freq'].sum() # Operations on the columns of a pandas data frame such as these below are vectorised operations.
    graph = lengths['Density'].plot(color = 'yellow', legend = False, ylabel = "Density", xlabel = "Length (minutes)", title = "Density of movie lengths")
    graph.patch.set_facecolor('blue')
    lengths['Freq'][2]
    lengths.index
    lengths['Density'] = lengths['Freq'] / lengths['Freq'].sum()
    lengths['Average contribution'] = lengths['Density'] * lengths.index
    return lengths

# %%
all_movies = length_distribution(movies)

# %%
all_movies['Average contribution'].sum()

# %% [markdown]
# The average (mean) film is 99 minutes long

# %%
print(all_movies['Density'][1:98].sum())
print(all_movies['Density'][1:99].sum())

# %% [markdown]
# The median film is 98 mintes long

# %% [markdown]
# The mean is marginally higher than the median. This is could be down to a few extream values (films over 300 minutes for example. Let's look at these films:

# %%
for i in range(len(movies)):
    film_len = int(movies['duration'].iloc[i][:-4])
    movies['duration'].iloc[i] = film_len
movies.sort_values('duration').iloc[-20:]

# %% [markdown]
# The longest item is an episode of Black Mirror. This episode was an 'interactive' movie. This means that the watching time in reality, is much lower than the quoted figure. The figure corresponds to the length of all the possible stories combined.
#
# Beyond this we see many of the longer films were produced in Egypt and India.

# %%
egypt_films = movies[movies.country == 'Egypt']
len(egypt_films)

# %%
egypt_films['duration'].mean()

# %%
egypt_films['duration'].median()

# %% [markdown]
# As hypothesised, these films have a longer than average length. Let's check the same for India too.

# %%
india_films = movies[movies.country == 'India']
len(india_films)

# %%
india_films['duration'].mean()

# %%
india_films['duration'].median()

# %% [markdown]
# These films are even longer than those from egypt.
# Let's try and find a country with shorter films.

# %%
movies.sort_values('duration').iloc[:20]

# %% [markdown]
# It appears the the US has shorter films than average.

# %%
us_films = movies[movies.country == 'United States']
len(us_films)

# %%
us_films['duration'].mean()

# %%
us_films['duration'].median()

# %% [markdown]
# The films from the US appear to have a smaller than average runtime. An interesting observation is that for every country, and in the full sample, the median length was almost equal to the mean length. The analysis strongly suggests than the country that the film is from is correlated to the length of the film.
#
# My analysis has several limitations. Firstly, Netflix only provide films that are popular. Thus, there is a chance that the films on Netflix are not representative of all films. For example, it could be that long films are less popular, so Netflix possess fewer long on their platform. Another limitation is the number of films from Egypt was relatively low, although, I don't think it was low enough to invalidate my results.

# %% [markdown]
# # Conclusion and Reflection

# %% [markdown]
# ## What have I done?
# ### My Code
# I have shown that I possess and excellent understanding of all the course materials. I have appropriately and effectively utilised all the required tools. My code fulfils all the criteria:
# Programming Skills: I have appropriately used an array of programming techniques including modularisation, functions, classes, pandas and others.
# Robustness: In the case of errors, a useful error is raised / message is provided to the user to highlight possible issues.
# Readability and Style: PEP 8 Style has been used throughout.
# Program Design: The questions have been decomposed into simple steps. An example of this is the cleaner function which takes text and cleans it. Being a function, I have been able to use it at different times when it was needed. The code was only written once (in the function) so it keeps it tidy and is easy to update.
# Testing: Throughout development my code has been tested to assure it works, where requested, I have provided testing.
# Self-Learning: I have used libraries not mentioned in this course. These include ateutil.relativedelta, collections.OrderedDict, matplotlib.pyplot.
# Analysis: I perform a sensible and informative analysis. Reflections are provided below.
# Communication: My report is clear and concise.

# %% [markdown]
# ## What are the limitations?
# Python possesses extensive libraries. While I have gone to effort to assure my code be as fast and efficient as possible, I'm sure there are countless ways to improve upon it.
#
# Code in general is also very rigid. It requires perfect inputs, otherwise it won't run.

# %% [markdown]
# ## What can be improved?
# For question three, my analysis is very simple. This is partly down to my inexperience with natural language processing. I'm unfamiliar with common and key analysis with text. If I had more time, I could have provided a more in-depth analysis, looking at other variables, possibly running a regression to see factors that have an effect on film length.
# Also, as previously mentioned, my code could probably be more efficient. For the large loop loading in the Netflix data to the streaming service, I could have used multiprocessing to speed it up.
# If I had more time, I could produce more features for question 2, making it more realistic. I could also update the search function to treat numbers properly regardless of how you write them, i.e., 'one' as 1.
